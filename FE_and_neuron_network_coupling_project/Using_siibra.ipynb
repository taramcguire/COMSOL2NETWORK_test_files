# %%
# siibra is a Python library that provides programmatic access to human brain atlases—especially the Julich-Brain Atlas—enabling 
#querying, downloading, and visualization of brain regions, maps, and connectivity data from the EBRAINS platform. this cell 
#we just testing different functions of siibra
import siibra
from nilearn import plotting, image
import matplotlib.pyplot as plt
import numpy as np
import nibabel as nib
import plotly.graph_objects as go
# Out:
# [siibra:INFO] Version: 1.0.1-alpha.10
# [siibra:WARNING] This is a development release. Use at your own risk.
# [siibra:INFO] Please file bugs and issues at https://github.com/FZJ-INM1-BDA/siibra-python.

# %%
#An instance table in Python refers to a table (usually a list of dictionaries or a DataFrame) 
#that contains data extracted from instances (objects) of a custom class.
# siibra uses instance tables not only for atlases, but also for parcellations
# (`siibra.parcellations`), reference spaces (`siibra.spaces`) or feature
# modalities (`siibra.modalities`), as will be shown in later code examples.
#
# Objects stored in a siibra instance table can be accessed in
# different ways:
#
#  1. In "list-style": by iterating over all objects or using the index operator "[]"
#  2. By fuzzy keyword matching via the get() function or index operator
#  3. By tab-completion of their "keys"
siibra.atlases.keys
# Out:
# Loading preconfigured Atlas instances: 100%|███████████████████████████████████████████| 5/5 [00:00<00:00,  6.23Atlas/s]
# ['MULTILEVEL_HUMAN_ATLAS',
#  'PRERELEASE_MARMOSET_ATLAS',
#  'MONKEY_ATLAS',
#  'ALLEN_MOUSE_COMMON_COORDINATE_FRAMEWORK_V3',
#  'WAXHOLM_SPACE_ATLAS_OF_THE_SPRAGUE_DAWLEY_RAT_BRAIN']

# %%
# The keys can be used to select atlas object by autocompletion
# when you hit <TAB>. This makes it convenient to find the right name
# in an interactive shell.
atlas = siibra.atlases.MULTILEVEL_HUMAN_ATLAS
atlas
# Out:
# <Atlas(identifier='juelich/iav/atlas/v1.0.0/1', name='Multilevel Human Atlas', species='Homo sapiens')>

# %%
# We can also select an atlas by specifying the key as a string
# in the get() method:
siibra.atlases.get("MULTILEVEL HUMAN ATLAS")
# Out:
# <Atlas(identifier='juelich/iav/atlas/v1.0.0/1', name='Multilevel Human Atlas', species='Homo sapiens')>

# %%
# More importantly, we can use an arbitrary set of words
# matching the name or key of atlas. This is usually the simplest way
# to select from a Registry. It will fail if no unique match is found.
siibra.atlases.get('human')
# Out:
# <Atlas(identifier='juelich/iav/atlas/v1.0.0/1', name='Multilevel Human Atlas', species='Homo sapiens')>

# %%
siibra.atlases[0]
siibra.atlases['human']
# Out:
# <Atlas(identifier='juelich/iav/atlas/v1.0.0/1', name='Multilevel Human Atlas', species='Homo sapiens')>

# %%
# The instance table can list the keys of all parcellations predefined in `siibra`.
# Note that this includes parcellations for all supported atlases.
siibra.parcellations.keys
# Out:
# Loading preconfigured Parcellation instances: 100%|██████████████████████████| 28/28 [00:00<00:00, 151.40Parcellation/s]
# ['DEEP_WHITE_MATTER_FIBRE_BUNDLES',
#  'SUPERFICIAL_FIBRE_BUNDLES',
#  'CORTICAL_LAYER_SEGMENTATION_OF_THE_BIGBRAIN_MODEL',
#  'DIFUMO_ATLAS_1024_DIMENSIONS',
#  'DIFUMO_ATLAS_128_DIMENSIONS',
#  'DIFUMO_ATLAS_256_DIMENSIONS',
#  'DIFUMO_ATLAS_512_DIMENSIONS',
#  'DIFUMO_ATLAS_64_DIMENSIONS',
#  'DESIKAN_KILLIANY_ATLAS_2006',
#  'HARVARDOXFORD_CORT_MAXPROB_THR0',
#  'HARVARDOXFORD_CORT_MAXPROB_THR25',
#  'ISOCORTEX_SEGMENTATION',
#  'JULICH_BRAIN_CYTOARCHITECTONIC_ATLAS_V1_18',
#  'JULICH_BRAIN_CYTOARCHITECTONIC_ATLAS_V2_9',
#  'JULICH_BRAIN_CYTOARCHITECTONIC_ATLAS_V3_0_3',
#  'JULICH_BRAIN_CYTOARCHITECTONIC_ATLAS_V3_1',
#  'MARMOSET_NENCKI_MONASH_ATLAS_2020',
#  'MARSATLAS_CORTICAL_PARCELLATION_MODEL',
#  'MEBRAINS_POPULATION_BASED_MONKEY_PARCELLATION',
#  'ALLEN_MOUSE_COMMON_COORDINATE_FRAMEWORK_V3_2015',
#  'ALLEN_MOUSE_COMMON_COORDINATE_FRAMEWORK_V3_2017',
#  'WAXHOLM_SPACE_ATLAS_OF_THE_SPRAGUE_DAWLEY_RAT_BRAIN_V1_01',
#  'WAXHOLM_SPACE_ATLAS_OF_THE_SPRAGUE_DAWLEY_RAT_BRAIN_V2',
#  'WAXHOLM_SPACE_ATLAS_OF_THE_SPRAGUE_DAWLEY_RAT_BRAIN_V3',
#  'WAXHOLM_SPACE_ATLAS_OF_THE_SPRAGUE_DAWLEY_RAT_BRAIN_V4',
#  'ATLAS_OF_THE_SHORT_FIBER_BUNDLES_INFERRED_FROM_THE_HUMAN_CONNECTOME_PROJECT_DIFFUSION_MRI_DATASET',
#  'VIRTUAL_EPILEPTIC_PATIENT_ATLAS',
#  'VON_ECONOMO_KOSKINAS_BRAIN_ATLAS']

# %%
# Fetching an object works in the same way as for `siibra.atlases` (see :ref:`atlases`)
julich_brain = siibra.parcellations.get('JULICH_BRAIN_CYTOARCHITECTONIC_ATLAS_V3_1')

# %%
# just look at a few metadata fields:
print("Name:    ", julich_brain.name)
print("Id:      ", julich_brain.id)
print("Modality:", julich_brain.modality)
print()
print(julich_brain.description)
print()
for p in julich_brain.publications:
    print(p['citation'])
# Out:
# Name:     Julich-Brain Cytoarchitectonic Atlas (v3.1)
# Id:       minds/core/parcellationatlas/v1.0.0/94c1125b-b87e-45e4-901c-00daee7f2579-310
# Modality: cytoarchitecture
#
# The Julich-Brain Atlas (RRID:SCR_023277) presents in this dataset cytoarchitectonicmaps in several coordinate spaces, such as MNI Colin 27, MNI ICBM 152, andFreeSurfer. These maps originate from peer-reviewed probability maps (PMs) that defineboth cortical and subcortical brain regions. Notably, these probability maps account forthe brain's inter-individual variability by analyzing data from ten post- mortem samples.For a whole-brain parcellation, the available probability maps are combined into amaximum probability map (MPM) by considering for each voxel the probability of allcytoarchitectonic brain regions, and determining the most probable assignment.Continuously evolving, the atlas is regularly updated with new areas. Furthermore, itstands as a reference atlas for the Human Brain Project and is deeply embedded withinthe European research infrastructure platform, EBRAINS. The siibra toolsuite providesan automated access to the Atlas, to speed up your work.
#
# Amunts, K., Mohlberg, H., Bludau, S., Zilles, K. (2020). Julich-Brain – A 3D probabilistic atlas of human brain’s cytoarchitecture. Science 369, 988-992
# Alan C. Evans, Andrew L. Janke, D. Louis Collins, Sylvain Baillet, Brain templates and atlases, NeuroImage, Volume 62, Issue 2, 2012, Pages 911-922, ISSN 1053-8119, https://doi.org/10.1016/j.neuroimage.2012.01.024.
# Simon B. Eickhoff, Klaas E. Stephan, Hartmut Mohlberg, Christian Grefkes, Gereon R. Fink, Katrin Amunts, Karl Zilles, A new SPM toolbox for combining probabilistic cytoarchitectonic maps and functional imaging data, NeuroImage, Volume 25, Issue 4, 2005, Pages 1325-1335, ISSN 1053-8119, https://doi.org/10.1016/j.neuroimage.2004.12.034.
# Dataset name: Julich-Brain Atlas, cytoarchitectonic maps (v3.1)

# %%
# The region hierarchy is a tree structure. Its default representation is a
# string of the tree.
julich_brain.render_tree()
# Out:
# Julich-Brain Cytoarchitectonic Atlas (v3.1)
# ├── telencephalon
# │   ├── cerebral nuclei
# │   │   ├── basal ganglia
# │   │   │   ├── ventral pallidum
# │   │   │   │   ╰── VP (Ventral Pallidum)
# │   │   │   │       ├── VP (Ventral Pallidum) right
# │   │   │   │       ╰── VP (Ventral Pallidum) left
# │   │   │   ╰── ventral striatum
# │   │   │       ├── FuCd (Ventral Striatum, Fundus of Caudate Nucleus)
# │   │   │       │   ├── FuCd (Ventral Striatum, Fundus of Caudate Nucleus) right
# │   │   │       │   ╰── FuCd (Ventral Striatum, Fundus of Caudate Nucleus) left
# │   │   │       ├── AcbM (Ventral Striatum, Medial Accumbens)
# │   │   │       │   ├── AcbM (Ventral Striatum, Medial Accumbens) right
# │   │   │       │   ╰── AcbM (Ventral Striatum, Medial Accumbens) left
# │   │   │       ├── AcbL (Ventral Striatum, Lateral Accumbens)
# │   │   │       │   ├── AcbL (Ventral Striatum, Lateral Accumbens) right
# │   │   │       │   ╰── AcbL (Ventral Striatum, Lateral Accumbens) left
# │   │   │       ╰── FuP (Ventral Striatum, Fundus of Putamen)
# │   │   │           ├── FuP (Ventral Striatum, Fundus of Putamen) right
# │   │   │           ╰── FuP (Ventral Striatum, Fundus of Putamen) left
# │   │   ├── basal forebrain
# │   │   │   ├── sublenticular basal forebrain
# │   │   │   │   ╰── Ch 4 (Basal Forebrain)
# │   │   │   │       ├── Ch 4 (Basal Forebrain) right
# │   │   │   │       ╰── Ch 4 (Basal Forebrain) left
# │   │   │   ├── bed nucleus
# │   │   │   │   ╰── BST (Basal Forebrain, Bed Nucleus)
# │   │   │   │       ├── BST (Basal Forebrain, Bed Nucleus) right
# │   │   │   │       ╰── BST (Basal Forebrain, Bed Nucleus) left
# │   │   │   ╰── magnocellular group
# │   │   │       ╰── Ch 123 (Basal Forebrain)
# │   │   │           ├── Ch 123 (Basal Forebrain) right
# │   │   │           ╰── Ch 123 (Basal Forebrain) left
# │   │   ╰── amygdala
# │   │       ├── amygdaloid groups
# │   │       │   ├── CM (Amygdala)
# │   │       │   │   ├── CM (Amygdala) right
# │   │       │   │   │   ├── CM.AAA (Amygdala) right
# │   │       │   │   │   ├── CM.Ce (Amygdala) right
# │   │       │   │   │   ╰── CM.Me (Amygdala) right
# │   │       │   │   ╰── CM (Amygdala) left
# │   │       │   │       ├── CM.AAA (Amygdala) left
# │   │       │   │       ├── CM.Ce (Amygdala) left
# │   │       │   │       ╰── CM.Me (Amygdala) left
# │   │       │   ├── LB (Amygdala)
# │   │       │   │   ├── LB (Amygdala) right
# │   │       │   │   │   ├── LB.Bl (Amygdala) right
# │   │       │   │   │   ├── LB.Bm (Amygdala) right
# │   │       │   │   │   ├── LB.Pl (Amygdala) right
# │   │       │   │   │   ╰── LB.La (Amygdala) right
# │   │       │   │   ╰── LB (Amygdala) left
# │   │       │   │       ├── LB.Bl (Amygdala) left
# │   │       │   │       ├── LB.Bm (Amygdala) left
# │   │       │   │       ├── LB.Pl (Amygdala) left
# │   │       │   │       ╰── LB.La (Amygdala) left
# │   │       │   ╰── SF (Amygdala)
# │   │       │       ├── SF (Amygdala) right
# │   │       │       │   ├── SF.AHi (Amygdala) right
# │   │       │       │   ├── SF.APir (Amygdala) right
# │   │       │       │   ╰── SF.VCo (Amygdala) right
# │   │       │       ╰── SF (Amygdala) left
# │   │       │           ├── SF.AHi (Amygdala) left
# │   │       │           ├── SF.APir (Amygdala) left
# │   │       │           ╰── SF.VCo (Amygdala) left
# │   │       ├── amygdalostriatal transition zone
# │   │       │   ╰── Astr (Amygdala)
# │   │       │       ├── Astr (Amygdala) right
# │   │       │       ╰── Astr (Amygdala) left
# │   │       ╰── fiber masses
# │   │           ├── VTM (Amygdala)
# │   │           │   ├── VTM (Amygdala) right
# │   │           │   ╰── VTM (Amygdala) left
# │   │           ├── IF (Amygdala)
# │   │           │   ├── IF (Amygdala) right
# │   │           │   │   ├── IF.ice (Amygdala) right
# │   │           │   │   ├── IF.iol (Amygdala) right
# │   │           │   │   ╰── IF.ld (Amygdala) right
# │   │           │   ╰── IF (Amygdala) left
# │   │           │       ├── IF.ice (Amygdala) left
# │   │           │       ├── IF.iol (Amygdala) left
# │   │           │       ╰── IF.ld (Amygdala) left
# │   │           ╰── MF (Amygdala)
# │   │               ├── MF (Amygdala) right
# │   │               │   ├── MF.icm (Amygdala) right
# │   │               │   ╰── MF.lm (Amygdala) right
# │   │               ╰── MF (Amygdala) left
# │   │                   ├── MF.icm (Amygdala) left
# │   │                   ╰── MF.lm (Amygdala) left
# │   ╰── cerebral cortex
# │       ├── parietal lobe
# │       │   ├── superior parietal lobule
# │       │   │   ├── Area 5L (SPL)
# │       │   │   │   ├── Area 5L (SPL) right
# │       │   │   │   ╰── Area 5L (SPL) left
# │       │   │   ├── Area 7M (SPL)
# │       │   │   │   ├── Area 7M (SPL) right
# │       │   │   │   ╰── Area 7M (SPL) left
# │       │   │   ├── Area 7PC (SPL)
# │       │   │   │   ├── Area 7PC (SPL) right
# │       │   │   │   ╰── Area 7PC (SPL) left
# │       │   │   ├── Area 5M (SPL)
# │       │   │   │   ├── Area 5M (SPL) right
# │       │   │   │   ╰── Area 5M (SPL) left
# │       │   │   ├── Area 7P (SPL)
# │       │   │   │   ├── Area 7P (SPL) right
# │       │   │   │   ╰── Area 7P (SPL) left
# │       │   │   ├── Area 5Ci (SPL)
# │       │   │   │   ├── Area 5Ci (SPL) right
# │       │   │   │   ╰── Area 5Ci (SPL) left
# │       │   │   ╰── Area 7A (SPL)
# │       │   │       ├── Area 7A (SPL) right
# │       │   │       ╰── Area 7A (SPL) left
# │       │   ├── postcentral gyrus
# │       │   │   ├── Area 3b (PostCG)
# │       │   │   │   ├── Area 3b (PostCG) right
# │       │   │   │   ╰── Area 3b (PostCG) left
# │       │   │   ├── Area 1 (PostCG)
# │       │   │   │   ├── Area 1 (PostCG) right
# │       │   │   │   ╰── Area 1 (PostCG) left
# │       │   │   ├── Area 2 (PostCS)
# │       │   │   │   ├── Area 2 (PostCS) right
# │       │   │   │   ╰── Area 2 (PostCS) left
# │       │   │   ╰── Area 3a (PostCG)
# │       │   │       ├── Area 3a (PostCG) right
# │       │   │       ╰── Area 3a (PostCG) left
# │       │   ├── parietal operculum
# │       │   │   ├── Area Op1 (POperc)
# │       │   │   │   ├── Area Op1 (POperc) right
# │       │   │   │   ╰── Area Op1 (POperc) left
# │       │   │   ├── Area Op2 (POperc)
# │       │   │   │   ├── Area Op2 (POperc) right
# │       │   │   │   ╰── Area Op2 (POperc) left
# │       │   │   ├── Area Op3 (POperc)
# │       │   │   │   ├── Area Op3 (POperc) right
# │       │   │   │   ╰── Area Op3 (POperc) left
# │       │   │   ╰── Area Op4 (POperc)
# │       │   │       ├── Area Op4 (POperc) right
# │       │   │       ╰── Area Op4 (POperc) left
# │       │   ├── inferior parietal lobule
# │       │   │   ├── Area PF (IPL)
# │       │   │   │   ├── Area PF (IPL) right
# │       │   │   │   ╰── Area PF (IPL) left
# │       │   │   ├── Area PFcm (IPL)
# │       │   │   │   ├── Area PFcm (IPL) right
# │       │   │   │   ╰── Area PFcm (IPL) left
# │       │   │   ├── Area PGa (IPL)
# │       │   │   │   ├── Area PGa (IPL) right
# │       │   │   │   ╰── Area PGa (IPL) left
# │       │   │   ├── Area PFt (IPL)
# │       │   │   │   ├── Area PFt (IPL) right
# │       │   │   │   ╰── Area PFt (IPL) left
# │       │   │   ├── Area PFm (IPL)
# │       │   │   │   ├── Area PFm (IPL) right
# │       │   │   │   ╰── Area PFm (IPL) left
# │       │   │   ├── Area PGp (IPL)
# │       │   │   │   ├── Area PGp (IPL) right
# │       │   │   │   ╰── Area PGp (IPL) left
# │       │   │   ╰── Area PFop (IPL)
# │       │   │       ├── Area PFop (IPL) right
# │       │   │       ╰── Area PFop (IPL) left
# │       │   ├── parieto-occipital sulcus
# │       │   │   ╰── Area hPO1 (POS)
# │       │   │       ├── Area hPO1 (POS) right
# │       │   │       ╰── Area hPO1 (POS) left
# │       │   ╰── intraparietal sulcus
# │       │       ├── Area hIP1 (IPS)
# │       │       │   ├── Area hIP1 (IPS) right
# │       │       │   ╰── Area hIP1 (IPS) left
# │       │       ├── Area hIP7 (IPS)
# │       │       │   ├── Area hIP7 (IPS) right
# │       │       │   ╰── Area hIP7 (IPS) left
# │       │       ├── Area hIP3 (IPS)
# │       │       │   ├── Area hIP3 (IPS) right
# │       │       │   ╰── Area hIP3 (IPS) left
# │       │       ├── Area hIP2 (IPS)
# │       │       │   ├── Area hIP2 (IPS) right
# │       │       │   ╰── Area hIP2 (IPS) left
# │       │       ├── Area hIP4 (IPS)
# │       │       │   ├── Area hIP4 (IPS) right
# │       │       │   ╰── Area hIP4 (IPS) left
# │       │       ├── Area hIP5 (IPS)
# │       │       │   ├── Area hIP5 (IPS) right
# │       │       │   ╰── Area hIP5 (IPS) left
# │       │       ├── Area hIP6 (IPS)
# │       │       │   ├── Area hIP6 (IPS) right
# │       │       │   ╰── Area hIP6 (IPS) left
# │       │       ╰── Area hIP8 (IPS)
# │       │           ├── Area hIP8 (IPS) right
# │       │           ╰── Area hIP8 (IPS) left
# │       ├── Frontal-to-Occipital (GapMap)
# │       │   ├── Frontal-to-Occipital (GapMap) right
# │       │   ╰── Frontal-to-Occipital (GapMap) left
# │       ├── Temporal-to-Parietal (GapMap)
# │       │   ├── Temporal-to-Parietal (GapMap) right
# │       │   ╰── Temporal-to-Parietal (GapMap) left
# │       ├── Frontal-I.2 (GapMap)
# │       │   ├── Frontal-I.2 (GapMap) right
# │       │   ╰── Frontal-I.2 (GapMap) left
# │       ├── Frontal-to-Temporal-II (GapMap)
# │       │   ├── Frontal-to-Temporal-II (GapMap) right
# │       │   ╰── Frontal-to-Temporal-II (GapMap) left
# │       ├── Frontal-I.1 (GapMap)
# │       │   ├── Frontal-I.1 (GapMap) right
# │       │   ╰── Frontal-I.1 (GapMap) left
# │       ├── Frontal-to-Temporal-I (GapMap)
# │       │   ├── Frontal-to-Temporal-I (GapMap) right
# │       │   ╰── Frontal-to-Temporal-I (GapMap) left
# │       ├── Frontal-II (GapMap)
# │       │   ├── Frontal-II (GapMap) right
# │       │   ╰── Frontal-II (GapMap) left
# │       ├── frontal lobe
# │       │   ├── ventral precentral gyrus
# │       │   │   ├── Area 6v3 (PreCG)
# │       │   │   │   ├── Area 6v3 (PreCG) right
# │       │   │   │   ╰── Area 6v3 (PreCG) left
# │       │   │   ├── Area 6v2 (PreCG)
# │       │   │   │   ├── Area 6v2 (PreCG) right
# │       │   │   │   ╰── Area 6v2 (PreCG) left
# │       │   │   ├── Area 6r1 (PreCG)
# │       │   │   │   ├── Area 6r1 (PreCG) right
# │       │   │   │   ╰── Area 6r1 (PreCG) left
# │       │   │   ╰── Area 6v1 (PreCG)
# │       │   │       ├── Area 6v1 (PreCG) right
# │       │   │       ╰── Area 6v1 (PreCG) left
# │       │   ├── dorsal precentral gyrus
# │       │   │   ├── Area 6d2 (PreCG)
# │       │   │   │   ├── Area 6d2 (PreCG) right
# │       │   │   │   ╰── Area 6d2 (PreCG) left
# │       │   │   ╰── Area 6d1 (PreCG)
# │       │   │       ├── Area 6d1 (PreCG) right
# │       │   │       ╰── Area 6d1 (PreCG) left
# │       │   ├── posterior medial superior frontal gyrus
# │       │   │   ╰── Area 6ma (preSMA, mesial SFG)
# │       │   │       ├── Area 6ma (preSMA, mesial SFG) right
# │       │   │       ╰── Area 6ma (preSMA, mesial SFG) left
# │       │   ├── frontal pole
# │       │   │   ├── Area Fp1 (FPole)
# │       │   │   │   ├── Area Fp1 (FPole) right
# │       │   │   │   ╰── Area Fp1 (FPole) left
# │       │   │   ╰── Area Fp2 (FPole)
# │       │   │       ├── Area Fp2 (FPole) right
# │       │   │       ╰── Area Fp2 (FPole) left
# │       │   ├── mesial precentral gyrus
# │       │   │   ╰── Area 6mp (SMA, mesial SFG)
# │       │   │       ├── Area 6mp (SMA, mesial SFG) right
# │       │   │       ╰── Area 6mp (SMA, mesial SFG) left
# │       │   ├── medial orbitofrontal cortex
# │       │   │   ├── Area Fo1 (OFC)
# │       │   │   │   ├── Area Fo1 (OFC) right
# │       │   │   │   ╰── Area Fo1 (OFC) left
# │       │   │   ├── Area Fo3 (OFC)
# │       │   │   │   ├── Area Fo3 (OFC) right
# │       │   │   │   ╰── Area Fo3 (OFC) left
# │       │   │   ╰── Area Fo2 (OFC)
# │       │   │       ├── Area Fo2 (OFC) right
# │       │   │       ╰── Area Fo2 (OFC) left
# │       │   ├── precentral gyrus
# │       │   │   ├── Area 4p (PreCG)
# │       │   │   │   ├── Area 4p (PreCG) right
# │       │   │   │   ╰── Area 4p (PreCG) left
# │       │   │   ╰── Area 4a (PreCG)
# │       │   │       ├── Area 4a (PreCG) right
# │       │   │       ╰── Area 4a (PreCG) left
# │       │   ├── frontal operculum
# │       │   │   ├── Area Op10 (Frontal Operculum)
# │       │   │   │   ├── Area Op10 (Frontal Operculum) right
# │       │   │   │   ╰── Area Op10 (Frontal Operculum) left
# │       │   │   ├── Area Op6 (Frontal Operculum)
# │       │   │   │   ├── Area Op6 (Frontal Operculum) right
# │       │   │   │   ╰── Area Op6 (Frontal Operculum) left
# │       │   │   ├── Area Op5 (Frontal Operculum)
# │       │   │   │   ├── Area Op5 (Frontal Operculum) right
# │       │   │   │   ╰── Area Op5 (Frontal Operculum) left
# │       │   │   ├── Area Op7 (Frontal Operculum)
# │       │   │   │   ├── Area Op7 (Frontal Operculum) right
# │       │   │   │   ╰── Area Op7 (Frontal Operculum) left
# │       │   │   ├── Area Op9 (Frontal Operculum)
# │       │   │   │   ├── Area Op9 (Frontal Operculum) right
# │       │   │   │   ╰── Area Op9 (Frontal Operculum) left
# │       │   │   ╰── Area Op8 (Frontal Operculum)
# │       │   │       ├── Area Op8 (Frontal Operculum) right
# │       │   │       ╰── Area Op8 (Frontal Operculum) left
# │       │   ├── inferior frontal sulcus
# │       │   │   ├── Area IFS4 (IFS)
# │       │   │   │   ├── Area IFS4 (IFS) right
# │       │   │   │   ╰── Area IFS4 (IFS) left
# │       │   │   ├── Area IFS2 (IFS)
# │       │   │   │   ├── Area IFS2 (IFS) right
# │       │   │   │   ╰── Area IFS2 (IFS) left
# │       │   │   ├── Area IFS1 (IFS)
# │       │   │   │   ├── Area IFS1 (IFS) right
# │       │   │   │   ╰── Area IFS1 (IFS) left
# │       │   │   ├── Area IFJ2 (IFS, PreCS)
# │       │   │   │   ├── Area IFJ2 (IFS, PreCS) right
# │       │   │   │   ╰── Area IFJ2 (IFS, PreCS) left
# │       │   │   ├── Area IFS3 (IFS)
# │       │   │   │   ├── Area IFS3 (IFS) right
# │       │   │   │   ╰── Area IFS3 (IFS) left
# │       │   │   ╰── Area IFJ1 (IFS, PreCS)
# │       │   │       ├── Area IFJ1 (IFS, PreCS) right
# │       │   │       ╰── Area IFJ1 (IFS, PreCS) left
# │       │   ├── fronto-marginal sulcus
# │       │   │   ╰── Area MFG2 (MFG)
# │       │   │       ├── Area MFG2 (MFG) right
# │       │   │       ╰── Area MFG2 (MFG) left
# │       │   ├── inferior frontal gyrus
# │       │   │   ├── Area 44 (IFG)
# │       │   │   │   ├── Area 44 (IFG) right
# │       │   │   │   ╰── Area 44 (IFG) left
# │       │   │   ╰── Area 45 (IFG)
# │       │   │       ├── Area 45 (IFG) right
# │       │   │       ╰── Area 45 (IFG) left
# │       │   ├── middle frontal gyrus
# │       │   │   ├── Area 8v2 (MFG)
# │       │   │   │   ├── Area 8v2 (MFG) right
# │       │   │   │   ╰── Area 8v2 (MFG) left
# │       │   │   ├── Area 8v1 (MFG)
# │       │   │   │   ├── Area 8v1 (MFG) right
# │       │   │   │   ╰── Area 8v1 (MFG) left
# │       │   │   ├── Area MFG4 (MFG)
# │       │   │   │   ├── Area MFG4 (MFG) right
# │       │   │   │   ╰── Area MFG4 (MFG) left
# │       │   │   ╰── Area MFG1 (MFG)
# │       │   │       ├── Area MFG1 (MFG) right
# │       │   │       ╰── Area MFG1 (MFG) left
# │       │   ├── superior frontal sulcus
# │       │   │   ├── Area SFS2 (SFS)
# │       │   │   │   ├── Area SFS2 (SFS) right
# │       │   │   │   ╰── Area SFS2 (SFS) left
# │       │   │   ├── Area 6d3 (SFS)
# │       │   │   │   ├── Area 6d3 (SFS) right
# │       │   │   │   ╰── Area 6d3 (SFS) left
# │       │   │   ├── Area SFS1 (SFS)
# │       │   │   │   ├── Area SFS1 (SFS) right
# │       │   │   │   ╰── Area SFS1 (SFS) left
# │       │   │   ╰── Area SFG3 (SFG)
# │       │   │       ├── Area SFG3 (SFG) right
# │       │   │       ╰── Area SFG3 (SFG) left
# │       │   ├── middle frontal gyrus, inferior frontal sulcus
# │       │   │   ╰── Area MFG5 (MFG, IFG)
# │       │   │       ├── Area MFG5 (MFG, IFG) right
# │       │   │       ╰── Area MFG5 (MFG, IFG) left
# │       │   ├── superior frontal gyrus
# │       │   │   ├── Area SFG2 (SFG)
# │       │   │   │   ├── Area SFG2 (SFG) right
# │       │   │   │   ╰── Area SFG2 (SFG) left
# │       │   │   ├── Area 8d2 (SFG)
# │       │   │   │   ├── Area 8d2 (SFG) right
# │       │   │   │   ╰── Area 8d2 (SFG) left
# │       │   │   ├── Area 8d1 (SFG)
# │       │   │   │   ├── Area 8d1 (SFG) right
# │       │   │   │   ╰── Area 8d1 (SFG) left
# │       │   │   ╰── Area SFG4 (SFG)
# │       │   │       ├── Area SFG4 (SFG) right
# │       │   │       ╰── Area SFG4 (SFG) left
# │       │   ╰── lateral orbitofrontal cortex
# │       │       ├── Area Fo6 (OFC)
# │       │       │   ├── Area Fo6 (OFC) right
# │       │       │   ╰── Area Fo6 (OFC) left
# │       │       ├── Area Fo5 (OFC)
# │       │       │   ├── Area Fo5 (OFC) right
# │       │       │   ╰── Area Fo5 (OFC) left
# │       │       ├── Area Fo7 (OFC)
# │       │       │   ├── Area Fo7 (OFC) right
# │       │       │   ╰── Area Fo7 (OFC) left
# │       │       ╰── Area Fo4 (OFC)
# │       │           ├── Area Fo4 (OFC) right
# │       │           ╰── Area Fo4 (OFC) left
# │       ├── insula
# │       │   ├── granular insula
# │       │   │   ├── Area Ig3 (Insula)
# │       │   │   │   ├── Area Ig3 (Insula) right
# │       │   │   │   ╰── Area Ig3 (Insula) left
# │       │   │   ├── Area Ig1 (Insula)
# │       │   │   │   ├── Area Ig1 (Insula) right
# │       │   │   │   ╰── Area Ig1 (Insula) left
# │       │   │   ╰── Area Ig2 (Insula)
# │       │   │       ├── Area Ig2 (Insula) right
# │       │   │       ╰── Area Ig2 (Insula) left
# │       │   ├── agranular insula
# │       │   │   ├── Area Ia2 (Insula)
# │       │   │   │   ├── Area Ia2 (Insula) right
# │       │   │   │   ╰── Area Ia2 (Insula) left
# │       │   │   ├── Area Ia1 (Insula)
# │       │   │   │   ├── Area Ia1 (Insula) right
# │       │   │   │   ╰── Area Ia1 (Insula) left
# │       │   │   ╰── Area Ia3 (Insula)
# │       │   │       ├── Area Ia3 (Insula) right
# │       │   │       ╰── Area Ia3 (Insula) left
# │       │   ╰── dysgranular insula
# │       │       ├── Area Id2 (Insula)
# │       │       │   ├── Area Id2 (Insula) right
# │       │       │   ╰── Area Id2 (Insula) left
# │       │       ├── Area Id8 (Insula)
# │       │       │   ├── Area Id8 (Insula) right
# │       │       │   ╰── Area Id8 (Insula) left
# │       │       ├── Area Id1 (Insula)
# │       │       │   ├── Area Id1 (Insula) right
# │       │       │   ╰── Area Id1 (Insula) left
# │       │       ├── Area Id9 (Insula)
# │       │       │   ├── Area Id9 (Insula) right
# │       │       │   ╰── Area Id9 (Insula) left
# │       │       ├── Area Id7 (Insula)
# │       │       │   ├── Area Id7 (Insula) right
# │       │       │   ╰── Area Id7 (Insula) left
# │       │       ├── Area Id5 (Insula)
# │       │       │   ├── Area Id5 (Insula) right
# │       │       │   ╰── Area Id5 (Insula) left
# │       │       ├── Area Id6 (Insula)
# │       │       │   ├── Area Id6 (Insula) right
# │       │       │   ╰── Area Id6 (Insula) left
# │       │       ├── Area Id10 (Insula)
# │       │       │   ├── Area Id10 (Insula) right
# │       │       │   ╰── Area Id10 (Insula) left
# │       │       ├── Area Id4 (Insula)
# │       │       │   ├── Area Id4 (Insula) right
# │       │       │   ╰── Area Id4 (Insula) left
# │       │       ╰── Area Id3 (Insula)
# │       │           ├── Area Id3 (Insula) right
# │       │           ╰── Area Id3 (Insula) left
# │       ├── temporal lobe
# │       │   ├── superior temporal sulcus
# │       │   │   ├── Area STS2 (STS)
# │       │   │   │   ├── Area STS2 (STS) right
# │       │   │   │   ╰── Area STS2 (STS) left
# │       │   │   ╰── Area STS1 (STS)
# │       │   │       ├── Area STS1 (STS) right
# │       │   │       ╰── Area STS1 (STS) left
# │       │   ├── occipito-temporal sulcus
# │       │   │   ╰── Area OTS1 (OTS)
# │       │   │       ├── Area OTS1 (OTS) right
# │       │   │       ╰── Area OTS1 (OTS) left
# │       │   ├── superior temporal gyrus
# │       │   │   ├── Area Te 3 (STG)
# │       │   │   │   ├── Area Te 3 (STG) right
# │       │   │   │   ╰── Area Te 3 (STG) left
# │       │   │   ├── Area Te 2.2 (STG)
# │       │   │   │   ├── Area Te 2.2 (STG) right
# │       │   │   │   ╰── Area Te 2.2 (STG) left
# │       │   │   ╰── Area Te 2.1 (STG)
# │       │   │       ├── Area Te 2.1 (STG) right
# │       │   │       ╰── Area Te 2.1 (STG) left
# │       │   ├── Heschl's gyrus
# │       │   │   ├── Area Te 1.1 (HESCHL)
# │       │   │   │   ├── Area Te 1.1 (HESCHL) right
# │       │   │   │   ╰── Area Te 1.1 (HESCHL) left
# │       │   │   ├── Area Te 1.2 (HESCHL)
# │       │   │   │   ├── Area Te 1.2 (HESCHL) right
# │       │   │   │   ╰── Area Te 1.2 (HESCHL) left
# │       │   │   ╰── Area Te 1.0 (HESCHL)
# │       │   │       ├── Area Te 1.0 (HESCHL) right
# │       │   │       ╰── Area Te 1.0 (HESCHL) left
# │       │   ├── parahippocampal gyrus
# │       │   │   ├── Area Ph1 (PhG)
# │       │   │   │   ├── Area Ph1 (PhG) right
# │       │   │   │   ╰── Area Ph1 (PhG) left
# │       │   │   ├── Area Ph2 (PhG)
# │       │   │   │   ├── Area Ph2 (PhG) right
# │       │   │   │   ╰── Area Ph2 (PhG) left
# │       │   │   ╰── Area Ph3 (PhG)
# │       │   │       ├── Area Ph3 (PhG) right
# │       │   │       ╰── Area Ph3 (PhG) left
# │       │   ├── collateral sulcus
# │       │   │   ╰── Area CoS1 (CoS)
# │       │   │       ├── Area CoS1 (CoS) right
# │       │   │       ╰── Area CoS1 (CoS) left
# │       │   ├── temporal insula
# │       │   │   ├── Area TI (STG)
# │       │   │   │   ├── Area TI (STG) right
# │       │   │   │   ╰── Area TI (STG) left
# │       │   │   ╰── Area TeI (STG)
# │       │   │       ├── Area TeI (STG) right
# │       │   │       ╰── Area TeI (STG) left
# │       │   ├── fusiform gyrus
# │       │   │   ├── Area FG5 (FusG)
# │       │   │   │   ├── Area FG5 (FusG) right
# │       │   │   │   ╰── Area FG5 (FusG) left
# │       │   │   ├── Area FG2 (FusG)
# │       │   │   │   ├── Area FG2 (FusG) right
# │       │   │   │   ╰── Area FG2 (FusG) left
# │       │   │   ├── Area FG3 (FusG)
# │       │   │   │   ├── Area FG3 (FusG) right
# │       │   │   │   ╰── Area FG3 (FusG) left
# │       │   │   ├── Area FG1 (FusG)
# │       │   │   │   ├── Area FG1 (FusG) right
# │       │   │   │   ╰── Area FG1 (FusG) left
# │       │   │   ╰── Area FG4 (FusG)
# │       │   │       ├── Area FG4 (FusG) right
# │       │   │       ╰── Area FG4 (FusG) left
# │       │   ╰── temporo-parietal junction
# │       │       ╰── Area TPJ (STG, SMG)
# │       │           ├── Area TPJ (STG, SMG) right
# │       │           ╰── Area TPJ (STG, SMG) left
# │       ├── occipital lobe
# │       │   ├── occipital cortex
# │       │   │   ├── Area hOc2 (V2, 18)
# │       │   │   │   ├── Area hOc2 (V2, 18) right
# │       │   │   │   ╰── Area hOc2 (V2, 18) left
# │       │   │   ╰── Area hOc1 (V1, 17, CalcS)
# │       │   │       ├── Area hOc1 (V1, 17, CalcS) right
# │       │   │       ╰── Area hOc1 (V1, 17, CalcS) left
# │       │   ├── dorsal occipital cortex
# │       │   │   ├── Area hOc6 (POS)
# │       │   │   │   ├── Area hOc6 (POS) right
# │       │   │   │   ╰── Area hOc6 (POS) left
# │       │   │   ├── Area hOc4d (Cuneus)
# │       │   │   │   ├── Area hOc4d (Cuneus) right
# │       │   │   │   ╰── Area hOc4d (Cuneus) left
# │       │   │   ╰── Area hOc3d (Cuneus)
# │       │   │       ├── Area hOc3d (Cuneus) right
# │       │   │       ╰── Area hOc3d (Cuneus) left
# │       │   ├── ventral occipital cortex
# │       │   │   ├── Area hOc3v (LingG)
# │       │   │   │   ├── Area hOc3v (LingG) right
# │       │   │   │   ╰── Area hOc3v (LingG) left
# │       │   │   ╰── Area hOc4v (LingG)
# │       │   │       ├── Area hOc4v (LingG) right
# │       │   │       ╰── Area hOc4v (LingG) left
# │       │   ╰── lateral occipital cortex
# │       │       ├── Area hOc4lp (LOC)
# │       │       │   ├── Area hOc4lp (LOC) right
# │       │       │   ╰── Area hOc4lp (LOC) left
# │       │       ├── Area hOc5 (LOC)
# │       │       │   ├── Area hOc5 (LOC) right
# │       │       │   ╰── Area hOc5 (LOC) left
# │       │       ╰── Area hOc4la (LOC)
# │       │           ├── Area hOc4la (LOC) right
# │       │           ╰── Area hOc4la (LOC) left
# │       ╰── limbic lobe
# │           ├── frontal cingulate gyrus
# │           │   ├── Area p24c (pACC)
# │           │   │   ├── Area p24c (pACC) right
# │           │   │   │   ├── Area p24c.pd24cd (pACC) right
# │           │   │   │   ├── Area p24c.pd24cv (pACC) right
# │           │   │   │   ╰── Area p24c.pv24c (pACC) right
# │           │   │   ╰── Area p24c (pACC) left
# │           │   │       ├── Area p24c.pd24cd (pACC) left
# │           │   │       ├── Area p24c.pd24cv (pACC) left
# │           │   │       ╰── Area p24c.pv24c (pACC) left
# │           │   ├── Area 25 (sACC)
# │           │   │   ├── Area 25 (sACC) right
# │           │   │   │   ├── Area 25.25a (sACC) right
# │           │   │   │   ╰── Area 25.25p (sACC) right
# │           │   │   ╰── Area 25 (sACC) left
# │           │   │       ├── Area 25.25a (sACC) left
# │           │   │       ╰── Area 25.25p (sACC) left
# │           │   ├── Area p24ab (pACC)
# │           │   │   ├── Area p24ab (pACC) right
# │           │   │   │   ├── Area p24ab.p24a (pACC) right
# │           │   │   │   ╰── Area p24ab.p24b (pACC) right
# │           │   │   ╰── Area p24ab (pACC) left
# │           │   │       ├── Area p24ab.p24a (pACC) left
# │           │   │       ╰── Area p24ab.p24b (pACC) left
# │           │   ├── Area s32 (sACC)
# │           │   │   ├── Area s32 (sACC) right
# │           │   │   ╰── Area s32 (sACC) left
# │           │   ├── Area 33 (ACC)
# │           │   │   ├── Area 33 (ACC) right
# │           │   │   ╰── Area 33 (ACC) left
# │           │   ├── Area p32 (pACC)
# │           │   │   ├── Area p32 (pACC) right
# │           │   │   ╰── Area p32 (pACC) left
# │           │   ╰── Area s24 (sACC)
# │           │       ├── Area s24 (sACC) right
# │           │       │   ├── Area s24.s24a (sACC) right
# │           │       │   ╰── Area s24.s24b (sACC) right
# │           │       ╰── Area s24 (sACC) left
# │           │           ├── Area s24.s24a (sACC) left
# │           │           ╰── Area s24.s24b (sACC) left
# │           ├── piriform cortex
# │           │   ├── Area PirT (PiriformCortexMesial, temporal)
# │           │   │   ├── Area PirT (PiriformCortexMesial, temporal) right
# │           │   │   │   ├── Area PirT.Tit (PiriformCortexMesial, Piriform temporal Area, Incisura temporalis) right
# │           │   │   │   ╰── Area PirT.Tu (PiriformCortexMesial, Piriform temporal Area, Uncus) right
# │           │   │   ╰── Area PirT (PiriformCortexMesial, temporal) left
# │           │   │       ├── Area PirT.Tit (PiriformCortexMesial, Piriform temporal Area, Incisura temporalis) left
# │           │   │       ╰── Area PirT.Tu (PiriformCortexMesial, Piriform temporal Area, Uncus) left
# │           │   ╰── Area PirTB (PiriformCortexMesial, temporobasal)
# │           │       ├── Area PirTB (PiriformCortexMesial, temporobasal) right
# │           │       │   ├── Area PirTB.TBd (PiriformCortexMesial, Piriform temporobasal Area, dorsal part) right
# │           │       │   ╰── Area PirTB.TBv (PiriformCortexMesial, Piriform temporobasal Area, ventral part) right
# │           │       ╰── Area PirTB (PiriformCortexMesial, temporobasal) left
# │           │           ├── Area PirTB.TBd (PiriformCortexMesial, Piriform temporobasal Area, dorsal part) left
# │           │           ╰── Area PirTB.TBv (PiriformCortexMesial, Piriform temporobasal Area, ventral part) left
# │           ├── hippocampal formation
# │           │   ├── HATA (Hippocampus)
# │           │   │   ├── HATA (Hippocampus) right
# │           │   │   ╰── HATA (Hippocampus) left
# │           │   ├── CA3 (Hippocampus)
# │           │   │   ├── CA3 (Hippocampus) right
# │           │   │   ╰── CA3 (Hippocampus) left
# │           │   ├── TrS (Hippocampus, Transsubiculum)
# │           │   │   ├── TrS (Hippocampus, Transsubiculum) right
# │           │   │   ╰── TrS (Hippocampus, Transsubiculum) left
# │           │   ├── Subc (Hippocampus, Subicular complex)
# │           │   │   ├── Subc (Hippocampus, Subicular complex) right
# │           │   │   │   ├── Subc.PaS (Hippocampus, Parasubiculum) right
# │           │   │   │   ├── Subc.PreS (Hippocampus, Presubiculum) right
# │           │   │   │   ├── Subc.ProS (Hippocampus, Prosubiculum) right
# │           │   │   │   ╰── Subc.Sub (Hippocampus, Subiculum) right
# │           │   │   ╰── Subc (Hippocampus, Subicular complex) left
# │           │   │       ├── Subc.PaS (Hippocampus, Parasubiculum) left
# │           │   │       ├── Subc.PreS (Hippocampus, Presubiculum) left
# │           │   │       ├── Subc.ProS (Hippocampus, Prosubiculum) left
# │           │   │       ╰── Subc.Sub (Hippocampus, Subiculum) left
# │           │   ├── DG (Hippocampus)
# │           │   │   ├── DG (Hippocampus) right
# │           │   │   ╰── DG (Hippocampus) left
# │           │   ├── CA2 (Hippocampus)
# │           │   │   ├── CA2 (Hippocampus) right
# │           │   │   ╰── CA2 (Hippocampus) left
# │           │   ├── Area EC (Hippocampal Region, Entorhinal Cortex)
# │           │   │   ├── Area EC (Hippocampal Region, Entorhinal Cortex) right
# │           │   │   ╰── Area EC (Hippocampal Region, Entorhinal Cortex) left
# │           │   ╰── CA1 (Hippocampus)
# │           │       ├── CA1 (Hippocampus) right
# │           │       ╰── CA1 (Hippocampus) left
# │           ╰── olfactory cortex
# │               ├── TuTi (Basal Forebrain, Terminal islands)
# │               │   ├── TuTi (Basal Forebrain, Terminal islands) right
# │               │   ╰── TuTi (Basal Forebrain, Terminal islands) left
# │               ╰── Tu (Basal Forebrain, Tuberculum)
# │                   ├── Tu (Basal Forebrain, Tuberculum) right
# │                   ╰── Tu (Basal Forebrain, Tuberculum) left
# ├── mesencephalon
# │   ╰── midbrain tegmentum
# │       ╰── midbrain
# │           ├── substantia nigra
# │           │   ├── SNC (Midbrain, Substantia Nigra pars compacta)
# │           │   │   ├── SNC (Midbrain, Substantia Nigra pars compacta) right
# │           │   │   ╰── SNC (Midbrain, Substantia Nigra pars compacta) left
# │           │   ╰── SNR (Midbrain, Substantia Nigra pars reticulata)
# │           │       ├── SNR (Midbrain, Substantia Nigra pars reticulata) right
# │           │       ╰── SNR (Midbrain, Substantia Nigra pars reticulata) left
# │           ├── nucleus ruber (parvocellular part)
# │           │   ╰── NRp (Midbrain, Nucleus Ruber, parvocellular part)
# │           │       ├── NRp (Midbrain, Nucleus Ruber, parvocellular part) right
# │           │       ╰── NRp (Midbrain, Nucleus Ruber, parvocellular part) left
# │           ╰── nucleus ruber (magnocellular part)
# │               ╰── NRm (Midbrain, Nucleus Ruber, magnocellular part)
# │                   ├── NRm (Midbrain, Nucleus Ruber, magnocellular part) right
# │                   ╰── NRm (Midbrain, Nucleus Ruber, magnocellular part) left
# ├── metencephalon
# │   ╰── cerebellum
# │       ╰── cerebellar nuclei
# │           ├── Ninterp (Cerebellum, Interposed Nucleus)
# │           │   ├── Ninterp (Cerebellum, Interposed Nucleus) right
# │           │   ╰── Ninterp (Cerebellum, Interposed Nucleus) left
# │           ├── dentate nucleus
# │           │   ├── Ndentv (Cerebellum, Ventral Dentate Nucleus)
# │           │   │   ├── Ndentv (Cerebellum, Ventral Dentate Nucleus) right
# │           │   │   ╰── Ndentv (Cerebellum, Ventral Dentate Nucleus) left
# │           │   ╰── Ndentd (Cerebellum, Dorsal Dentate Nucleus)
# │           │       ├── Ndentd (Cerebellum, Dorsal Dentate Nucleus) right
# │           │       ╰── Ndentd (Cerebellum, Dorsal Dentate Nucleus) left
# │           ╰── fastigial nucleus
# │               ╰── Nfast (Cerebellum, Fastigial Nucleus)
# │                   ├── Nfast (Cerebellum, Fastigial Nucleus) right
# │                   ╰── Nfast (Cerebellum, Fastigial Nucleus) left
# ╰── diencephalon
#     ├── subthalamus
#     │   ╰── STN (Subthalamus)
#     │       ├── STN (Subthalamus) right
#     │       ╰── STN (Subthalamus) left
#     ╰── thalamus
#         ├── ventral thalamus
#         │   ├── Rt (Thalamus, reticular Nucleus)
#         │   │   ├── Rt (Thalamus, reticular Nucleus) right
#         │   │   ╰── Rt (Thalamus, reticular Nucleus) left
#         │   ╰── ZI (Thalamus, zona incerta)
#         │       ├── ZI (Thalamus, zona incerta) right
#         │       ╰── ZI (Thalamus, zona incerta) left
#         ├── metathalamus
#         │   ├── medial geniculate body
#         │   │   ╰── CGM (Metathalamus)
#         │   │       ├── CGM (Metathalamus) right
#         │   │       ╰── CGM (Metathalamus) left
#         │   ╰── lateral geniculate body
#         │       ╰── CGL (Metathalamus)
#         │           ├── CGL (Metathalamus) right
#         │           ╰── CGL (Metathalamus) left
#         ╰── dorsal thalamus
#             ├── medial group
#             │   ├── MV (Thalamus, medioventral Nucleus)
#             │   │   ├── MV (Thalamus, medioventral Nucleus) right
#             │   │   ╰── MV (Thalamus, medioventral Nucleus) left
#             │   ├── MD (Thalamus, mediodorsal Nucleus)
#             │   │   ├── MD (Thalamus, mediodorsal Nucleus) right
#             │   │   ╰── MD (Thalamus, mediodorsal Nucleus) left
#             │   ╰── Pv (Thalamus, paraventricular Nucleus)
#             │       ├── Pv (Thalamus, paraventricular Nucleus) right
#             │       ╰── Pv (Thalamus, paraventricular Nucleus) left
#             ├── posterior group
#             │   ├── Po (Thalamus, posterior Nucleus)
#             │   │   ├── Po (Thalamus, posterior Nucleus) right
#             │   │   ╰── Po (Thalamus, posterior Nucleus) left
#             │   ├── PUm (Thalamus, medial pulvinar)
#             │   │   ├── PUm (Thalamus, medial pulvinar) right
#             │   │   ╰── PUm (Thalamus, medial pulvinar) left
#             │   ├── PUl (Thalamus, lateral pulvinar)
#             │   │   ├── PUl (Thalamus, lateral pulvinar) right
#             │   │   ╰── PUl (Thalamus, lateral pulvinar) left
#             │   ├── Li (Thalamus, limitans Nucleus)
#             │   │   ├── Li (Thalamus, limitans Nucleus) right
#             │   │   ╰── Li (Thalamus, limitans Nucleus) left
#             │   ├── Sg (Thalamus, suprageniculate Nucleus)
#             │   │   ├── Sg (Thalamus, suprageniculate Nucleus) right
#             │   │   ╰── Sg (Thalamus, suprageniculate Nucleus) left
#             │   ├── LP (Thalamus, lateral posterior Nucleus)
#             │   │   ├── LP (Thalamus, lateral posterior Nucleus) right
#             │   │   ╰── LP (Thalamus, lateral posterior Nucleus) left
#             │   ├── PUi (Thalamus, inferior pulvinar)
#             │   │   ├── PUi (Thalamus, inferior pulvinar) right
#             │   │   ╰── PUi (Thalamus, inferior pulvinar) left
#             │   ╰── PUa (Thalamus, anterior pulvinar)
#             │       ├── PUa (Thalamus, anterior pulvinar) right
#             │       ╰── PUa (Thalamus, anterior pulvinar) left
#             ├── anterior group
#             │   ├── LD (Thalamus, lateral dorsal Nucleus)
#             │   │   ├── LD (Thalamus, lateral dorsal Nucleus) right
#             │   │   ╰── LD (Thalamus, lateral dorsal Nucleus) left
#             │   ├── AV (Thalamus, anteroventral Nucleus)
#             │   │   ├── AV (Thalamus, anteroventral Nucleus) right
#             │   │   ╰── AV (Thalamus, anteroventral Nucleus) left
#             │   ╰── AM (Thalamus, anteromedial Nucleus)
#             │       ├── AM (Thalamus, anteromedial Nucleus) right
#             │       ╰── AM (Thalamus, anteromedial Nucleus) left
#             ├── ventral group
#             │   ├── VPMpc (Thalamus, ventral posterior medial Nucleus, parvocellular part)
#             │   │   ├── VPMpc (Thalamus, ventral posterior medial Nucleus, parvocellular part) right
#             │   │   ╰── VPMpc (Thalamus, ventral posterior medial Nucleus, parvocellular part) left
#             │   ├── VPi (Thalamus, ventroposterior inferior Nucleus)
#             │   │   ├── VPi (Thalamus, ventroposterior inferior Nucleus) right
#             │   │   ╰── VPi (Thalamus, ventroposterior inferior Nucleus) left
#             │   ├── VPL (Thalamus, ventral posterior lateral Nucleus)
#             │   │   ├── VPL (Thalamus, ventral posterior lateral Nucleus) right
#             │   │   ╰── VPL (Thalamus, ventral posterior lateral Nucleus) left
#             │   ├── VLP (Thalamus, ventral lateral posterior Nucleus)
#             │   │   ├── VLP (Thalamus, ventral lateral posterior Nucleus) right
#             │   │   ╰── VLP (Thalamus, ventral lateral posterior Nucleus) left
#             │   ├── VIM (Thalamus, ventral intermediate Nucleus)
#             │   │   ├── VIM (Thalamus, ventral intermediate Nucleus) right
#             │   │   ╰── VIM (Thalamus, ventral intermediate Nucleus) left
#             │   ├── VM (Thalamus, ventral medial Nucleus)
#             │   │   ├── VM (Thalamus, ventral medial Nucleus) right
#             │   │   ╰── VM (Thalamus, ventral medial Nucleus) left
#             │   ├── VA (Thalamus, ventral anterior Nucleus (ventral))
#             │   │   ├── VA (Thalamus, ventral anterior Nucleus (ventral)) right
#             │   │   ╰── VA (Thalamus, ventral anterior Nucleus (ventral)) left
#             │   ├── VLA (Thalamus, ventral lateral anterior Nucleus)
#             │   │   ├── VLA (Thalamus, ventral lateral anterior Nucleus) right
#             │   │   ╰── VLA (Thalamus, ventral lateral anterior Nucleus) left
#             │   ├── VAmc (Thalamus, ventral anterior Nucleus, magnocellular part)
#             │   │   ├── VAmc (Thalamus, ventral anterior Nucleus, magnocellular part) right
#             │   │   ╰── VAmc (Thalamus, ventral anterior Nucleus, magnocellular part) left
#             │   ╰── VPM (Thalamus, ventral posterior medial Nucleus)
#             │       ├── VPM (Thalamus, ventral posterior medial Nucleus) right
#             │       ╰── VPM (Thalamus, ventral posterior medial Nucleus) left
#             ╰── intralaminar group
#                 ├── sPf (Thalamus, subparafascicular Nucleus)
#                 │   ├── sPf (Thalamus, subparafascicular Nucleus) right
#                 │   ╰── sPf (Thalamus, subparafascicular Nucleus) left
#                 ├── Pf (Thalamus, parafascicular Nucleus)
#                 │   ├── Pf (Thalamus, parafascicular Nucleus) right
#                 │   ╰── Pf (Thalamus, parafascicular Nucleus) left
#                 ├── CM (Thalamus, centromedian Nucleus)
#                 │   ├── CM (Thalamus, centromedian Nucleus) right
#                 │   ╰── CM (Thalamus, centromedian Nucleus) left
#                 ╰── CL (Thalamus, anterior intralaminar nuclei)
#                     ├── CL (Thalamus, anterior intralaminar nuclei) right
#                     ╰── CL (Thalamus, anterior intralaminar nuclei) left

# %%
# Each node is a `Region` object, including the root node.
# We can iterate all regions in a parcellation
[region.name for region in julich_brain]
# Out:
# ['Julich-Brain Cytoarchitectonic Atlas (v3.1)',
#  'telencephalon',
#  'cerebral nuclei',
#  'basal ganglia',
#  'ventral pallidum',
#  'VP (Ventral Pallidum)',
#  'VP (Ventral Pallidum) right',
#  'VP (Ventral Pallidum) left',
#  'ventral striatum',
#  'FuCd (Ventral Striatum, Fundus of Caudate Nucleus)',
#  'FuCd (Ventral Striatum, Fundus of Caudate Nucleus) right',
#  'FuCd (Ventral Striatum, Fundus of Caudate Nucleus) left',
#  'AcbM (Ventral Striatum, Medial Accumbens)',
#  'AcbM (Ventral Striatum, Medial Accumbens) right',
#  'AcbM (Ventral Striatum, Medial Accumbens) left',
#  'AcbL (Ventral Striatum, Lateral Accumbens)',
#  'AcbL (Ventral Striatum, Lateral Accumbens) right',
#  'AcbL (Ventral Striatum, Lateral Accumbens) left',
#  'FuP (Ventral Striatum, Fundus of Putamen)',
#  'FuP (Ventral Striatum, Fundus of Putamen) right',
#  'FuP (Ventral Striatum, Fundus of Putamen) left',
#  'basal forebrain',
#  'sublenticular basal forebrain',
#  'Ch 4 (Basal Forebrain)',
#  'Ch 4 (Basal Forebrain) right',
#  'Ch 4 (Basal Forebrain) left',
#  'bed nucleus',
#  'BST (Basal Forebrain, Bed Nucleus)',
#  'BST (Basal Forebrain, Bed Nucleus) right',
#  'BST (Basal Forebrain, Bed Nucleus) left',
#  'magnocellular group',
#  'Ch 123 (Basal Forebrain)',
#  'Ch 123 (Basal Forebrain) right',
#  'Ch 123 (Basal Forebrain) left',
#  'amygdala',
#  'amygdaloid groups',
#  'CM (Amygdala)',
#  'CM (Amygdala) right',
#  'CM.AAA (Amygdala) right',
#  'CM.Ce (Amygdala) right',
#  'CM.Me (Amygdala) right',
#  'CM (Amygdala) left',
#  'CM.AAA (Amygdala) left',
#  'CM.Ce (Amygdala) left',
#  'CM.Me (Amygdala) left',
#  'LB (Amygdala)',
#  'LB (Amygdala) right',
#  'LB.Bl (Amygdala) right',
#  'LB.Bm (Amygdala) right',
#  'LB.Pl (Amygdala) right',
#  'LB.La (Amygdala) right',
#  'LB (Amygdala) left',
#  'LB.Bl (Amygdala) left',
#  'LB.Bm (Amygdala) left',
#  'LB.Pl (Amygdala) left',
#  'LB.La (Amygdala) left',
#  'SF (Amygdala)',
#  'SF (Amygdala) right',
#  'SF.AHi (Amygdala) right',
#  'SF.APir (Amygdala) right',
#  'SF.VCo (Amygdala) right',
#  'SF (Amygdala) left',
#  'SF.AHi (Amygdala) left',
#  'SF.APir (Amygdala) left',
#  'SF.VCo (Amygdala) left',
#  'amygdalostriatal transition zone',
#  'Astr (Amygdala)',
#  'Astr (Amygdala) right',
#  'Astr (Amygdala) left',
#  'fiber masses',
#  'VTM (Amygdala)',
#  'VTM (Amygdala) right',
#  'VTM (Amygdala) left',
#  'IF (Amygdala)',
#  'IF (Amygdala) right',
#  'IF.ice (Amygdala) right',
#  'IF.iol (Amygdala) right',
#  'IF.ld (Amygdala) right',
#  'IF (Amygdala) left',
#  'IF.ice (Amygdala) left',
#  'IF.iol (Amygdala) left',
#  'IF.ld (Amygdala) left',
#  'MF (Amygdala)',
#  'MF (Amygdala) right',
#  'MF.icm (Amygdala) right',
#  'MF.lm (Amygdala) right',
#  'MF (Amygdala) left',
#  'MF.icm (Amygdala) left',
#  'MF.lm (Amygdala) left',
#  'cerebral cortex',
#  'parietal lobe',
#  'superior parietal lobule',
#  'Area 5L (SPL)',
#  'Area 5L (SPL) right',
#  'Area 5L (SPL) left',
#  'Area 7M (SPL)',
#  'Area 7M (SPL) right',
#  'Area 7M (SPL) left',
#  'Area 7PC (SPL)',
#  'Area 7PC (SPL) right',
#  'Area 7PC (SPL) left',
#  'Area 5M (SPL)',
#  'Area 5M (SPL) right',
#  'Area 5M (SPL) left',
#  'Area 7P (SPL)',
#  'Area 7P (SPL) right',
#  'Area 7P (SPL) left',
#  'Area 5Ci (SPL)',
#  'Area 5Ci (SPL) right',
#  'Area 5Ci (SPL) left',
#  'Area 7A (SPL)',
#  'Area 7A (SPL) right',
#  'Area 7A (SPL) left',
#  'postcentral gyrus',
#  'Area 3b (PostCG)',
#  'Area 3b (PostCG) right',
#  'Area 3b (PostCG) left',
#  'Area 1 (PostCG)',
#  'Area 1 (PostCG) right',
#  'Area 1 (PostCG) left',
#  'Area 2 (PostCS)',
#  'Area 2 (PostCS) right',
#  'Area 2 (PostCS) left',
#  'Area 3a (PostCG)',
#  'Area 3a (PostCG) right',
#  'Area 3a (PostCG) left',
#  'parietal operculum',
#  'Area Op1 (POperc)',
#  'Area Op1 (POperc) right',
#  'Area Op1 (POperc) left',
#  'Area Op2 (POperc)',
#  'Area Op2 (POperc) right',
#  'Area Op2 (POperc) left',
#  'Area Op3 (POperc)',
#  'Area Op3 (POperc) right',
#  'Area Op3 (POperc) left',
#  'Area Op4 (POperc)',
#  'Area Op4 (POperc) right',
#  'Area Op4 (POperc) left',
#  'inferior parietal lobule',
#  'Area PF (IPL)',
#  'Area PF (IPL) right',
#  'Area PF (IPL) left',
#  'Area PFcm (IPL)',
#  'Area PFcm (IPL) right',
#  'Area PFcm (IPL) left',
#  'Area PGa (IPL)',
#  'Area PGa (IPL) right',
#  'Area PGa (IPL) left',
#  'Area PFt (IPL)',
#  'Area PFt (IPL) right',
#  'Area PFt (IPL) left',
#  'Area PFm (IPL)',
#  'Area PFm (IPL) right',
#  'Area PFm (IPL) left',
#  'Area PGp (IPL)',
#  'Area PGp (IPL) right',
#  'Area PGp (IPL) left',
#  'Area PFop (IPL)',
#  'Area PFop (IPL) right',
#  'Area PFop (IPL) left',
#  'parieto-occipital sulcus',
#  'Area hPO1 (POS)',
#  'Area hPO1 (POS) right',
#  'Area hPO1 (POS) left',
#  'intraparietal sulcus',
#  'Area hIP1 (IPS)',
#  'Area hIP1 (IPS) right',
#  'Area hIP1 (IPS) left',
#  'Area hIP7 (IPS)',
#  'Area hIP7 (IPS) right',
#  'Area hIP7 (IPS) left',
#  'Area hIP3 (IPS)',
#  'Area hIP3 (IPS) right',
#  'Area hIP3 (IPS) left',
#  'Area hIP2 (IPS)',
#  'Area hIP2 (IPS) right',
#  'Area hIP2 (IPS) left',
#  'Area hIP4 (IPS)',
#  'Area hIP4 (IPS) right',
#  'Area hIP4 (IPS) left',
#  'Area hIP5 (IPS)',
#  'Area hIP5 (IPS) right',
#  'Area hIP5 (IPS) left',
#  'Area hIP6 (IPS)',
#  'Area hIP6 (IPS) right',
#  'Area hIP6 (IPS) left',
#  'Area hIP8 (IPS)',
#  'Area hIP8 (IPS) right',
#  'Area hIP8 (IPS) left',
#  'Frontal-to-Occipital (GapMap)',
#  'Frontal-to-Occipital (GapMap) right',
#  'Frontal-to-Occipital (GapMap) left',
#  'Temporal-to-Parietal (GapMap)',
#  'Temporal-to-Parietal (GapMap) right',
#  'Temporal-to-Parietal (GapMap) left',
#  'Frontal-I.2 (GapMap)',
#  'Frontal-I.2 (GapMap) right',
#  'Frontal-I.2 (GapMap) left',
#  'Frontal-to-Temporal-II (GapMap)',
#  'Frontal-to-Temporal-II (GapMap) right',
#  'Frontal-to-Temporal-II (GapMap) left',
#  'Frontal-I.1 (GapMap)',
#  'Frontal-I.1 (GapMap) right',
#  'Frontal-I.1 (GapMap) left',
#  'Frontal-to-Temporal-I (GapMap)',
#  'Frontal-to-Temporal-I (GapMap) right',
#  'Frontal-to-Temporal-I (GapMap) left',
#  'Frontal-II (GapMap)',
#  'Frontal-II (GapMap) right',
#  'Frontal-II (GapMap) left',
#  'frontal lobe',
#  'ventral precentral gyrus',
#  'Area 6v3 (PreCG)',
#  'Area 6v3 (PreCG) right',
#  'Area 6v3 (PreCG) left',
#  'Area 6v2 (PreCG)',
#  'Area 6v2 (PreCG) right',
#  'Area 6v2 (PreCG) left',
#  'Area 6r1 (PreCG)',
#  'Area 6r1 (PreCG) right',
#  'Area 6r1 (PreCG) left',
#  'Area 6v1 (PreCG)',
#  'Area 6v1 (PreCG) right',
#  'Area 6v1 (PreCG) left',
#  'dorsal precentral gyrus',
#  'Area 6d2 (PreCG)',
#  'Area 6d2 (PreCG) right',
#  'Area 6d2 (PreCG) left',
#  'Area 6d1 (PreCG)',
#  'Area 6d1 (PreCG) right',
#  'Area 6d1 (PreCG) left',
#  'posterior medial superior frontal gyrus',
#  'Area 6ma (preSMA, mesial SFG)',
#  'Area 6ma (preSMA, mesial SFG) right',
#  'Area 6ma (preSMA, mesial SFG) left',
#  'frontal pole',
#  'Area Fp1 (FPole)',
#  'Area Fp1 (FPole) right',
#  'Area Fp1 (FPole) left',
#  'Area Fp2 (FPole)',
#  'Area Fp2 (FPole) right',
#  'Area Fp2 (FPole) left',
#  'mesial precentral gyrus',
#  'Area 6mp (SMA, mesial SFG)',
#  'Area 6mp (SMA, mesial SFG) right',
#  'Area 6mp (SMA, mesial SFG) left',
#  'medial orbitofrontal cortex',
#  'Area Fo1 (OFC)',
#  'Area Fo1 (OFC) right',
#  'Area Fo1 (OFC) left',
#  'Area Fo3 (OFC)',
#  'Area Fo3 (OFC) right',
#  'Area Fo3 (OFC) left',
#  'Area Fo2 (OFC)',
#  'Area Fo2 (OFC) right',
#  'Area Fo2 (OFC) left',
#  'precentral gyrus',
#  'Area 4p (PreCG)',
#  'Area 4p (PreCG) right',
#  'Area 4p (PreCG) left',
#  'Area 4a (PreCG)',
#  'Area 4a (PreCG) right',
#  'Area 4a (PreCG) left',
#  'frontal operculum',
#  'Area Op10 (Frontal Operculum)',
#  'Area Op10 (Frontal Operculum) right',
#  'Area Op10 (Frontal Operculum) left',
#  'Area Op6 (Frontal Operculum)',
#  'Area Op6 (Frontal Operculum) right',
#  'Area Op6 (Frontal Operculum) left',
#  'Area Op5 (Frontal Operculum)',
#  'Area Op5 (Frontal Operculum) right',
#  'Area Op5 (Frontal Operculum) left',
#  'Area Op7 (Frontal Operculum)',
#  'Area Op7 (Frontal Operculum) right',
#  'Area Op7 (Frontal Operculum) left',
#  'Area Op9 (Frontal Operculum)',
#  'Area Op9 (Frontal Operculum) right',
#  'Area Op9 (Frontal Operculum) left',
#  'Area Op8 (Frontal Operculum)',
#  'Area Op8 (Frontal Operculum) right',
#  'Area Op8 (Frontal Operculum) left',
#  'inferior frontal sulcus',
#  'Area IFS4 (IFS)',
#  'Area IFS4 (IFS) right',
#  'Area IFS4 (IFS) left',
#  'Area IFS2 (IFS)',
#  'Area IFS2 (IFS) right',
#  'Area IFS2 (IFS) left',
#  'Area IFS1 (IFS)',
#  'Area IFS1 (IFS) right',
#  'Area IFS1 (IFS) left',
#  'Area IFJ2 (IFS, PreCS)',
#  'Area IFJ2 (IFS, PreCS) right',
#  'Area IFJ2 (IFS, PreCS) left',
#  'Area IFS3 (IFS)',
#  'Area IFS3 (IFS) right',
#  'Area IFS3 (IFS) left',
#  'Area IFJ1 (IFS, PreCS)',
#  'Area IFJ1 (IFS, PreCS) right',
#  'Area IFJ1 (IFS, PreCS) left',
#  'fronto-marginal sulcus',
#  'Area MFG2 (MFG)',
#  'Area MFG2 (MFG) right',
#  'Area MFG2 (MFG) left',
#  'inferior frontal gyrus',
#  'Area 44 (IFG)',
#  'Area 44 (IFG) right',
#  'Area 44 (IFG) left',
#  'Area 45 (IFG)',
#  'Area 45 (IFG) right',
#  'Area 45 (IFG) left',
#  'middle frontal gyrus',
#  'Area 8v2 (MFG)',
#  'Area 8v2 (MFG) right',
#  'Area 8v2 (MFG) left',
#  'Area 8v1 (MFG)',
#  'Area 8v1 (MFG) right',
#  'Area 8v1 (MFG) left',
#  'Area MFG4 (MFG)',
#  'Area MFG4 (MFG) right',
#  'Area MFG4 (MFG) left',
#  'Area MFG1 (MFG)',
#  'Area MFG1 (MFG) right',
#  'Area MFG1 (MFG) left',
#  'superior frontal sulcus',
#  'Area SFS2 (SFS)',
#  'Area SFS2 (SFS) right',
#  'Area SFS2 (SFS) left',
#  'Area 6d3 (SFS)',
#  'Area 6d3 (SFS) right',
#  'Area 6d3 (SFS) left',
#  'Area SFS1 (SFS)',
#  'Area SFS1 (SFS) right',
#  'Area SFS1 (SFS) left',
#  'Area SFG3 (SFG)',
#  'Area SFG3 (SFG) right',
#  'Area SFG3 (SFG) left',
#  'middle frontal gyrus, inferior frontal sulcus',
#  'Area MFG5 (MFG, IFG)',
#  'Area MFG5 (MFG, IFG) right',
#  'Area MFG5 (MFG, IFG) left',
#  'superior frontal gyrus',
#  'Area SFG2 (SFG)',
#  'Area SFG2 (SFG) right',
#  'Area SFG2 (SFG) left',
#  'Area 8d2 (SFG)',
#  'Area 8d2 (SFG) right',
#  'Area 8d2 (SFG) left',
#  'Area 8d1 (SFG)',
#  'Area 8d1 (SFG) right',
#  'Area 8d1 (SFG) left',
#  'Area SFG4 (SFG)',
#  'Area SFG4 (SFG) right',
#  'Area SFG4 (SFG) left',
#  'lateral orbitofrontal cortex',
#  'Area Fo6 (OFC)',
#  'Area Fo6 (OFC) right',
#  'Area Fo6 (OFC) left',
#  'Area Fo5 (OFC)',
#  'Area Fo5 (OFC) right',
#  'Area Fo5 (OFC) left',
#  'Area Fo7 (OFC)',
#  'Area Fo7 (OFC) right',
#  'Area Fo7 (OFC) left',
#  'Area Fo4 (OFC)',
#  'Area Fo4 (OFC) right',
#  'Area Fo4 (OFC) left',
#  'insula',
#  'granular insula',
#  'Area Ig3 (Insula)',
#  'Area Ig3 (Insula) right',
#  'Area Ig3 (Insula) left',
#  'Area Ig1 (Insula)',
#  'Area Ig1 (Insula) right',
#  'Area Ig1 (Insula) left',
#  'Area Ig2 (Insula)',
#  'Area Ig2 (Insula) right',
#  'Area Ig2 (Insula) left',
#  'agranular insula',
#  'Area Ia2 (Insula)',
#  'Area Ia2 (Insula) right',
#  'Area Ia2 (Insula) left',
#  'Area Ia1 (Insula)',
#  'Area Ia1 (Insula) right',
#  'Area Ia1 (Insula) left',
#  'Area Ia3 (Insula)',
#  'Area Ia3 (Insula) right',
#  'Area Ia3 (Insula) left',
#  'dysgranular insula',
#  'Area Id2 (Insula)',
#  'Area Id2 (Insula) right',
#  'Area Id2 (Insula) left',
#  'Area Id8 (Insula)',
#  'Area Id8 (Insula) right',
#  'Area Id8 (Insula) left',
#  'Area Id1 (Insula)',
#  'Area Id1 (Insula) right',
#  'Area Id1 (Insula) left',
#  'Area Id9 (Insula)',
#  'Area Id9 (Insula) right',
#  'Area Id9 (Insula) left',
#  'Area Id7 (Insula)',
#  'Area Id7 (Insula) right',
#  'Area Id7 (Insula) left',
#  'Area Id5 (Insula)',
#  'Area Id5 (Insula) right',
#  'Area Id5 (Insula) left',
#  'Area Id6 (Insula)',
#  'Area Id6 (Insula) right',
#  'Area Id6 (Insula) left',
#  'Area Id10 (Insula)',
#  'Area Id10 (Insula) right',
#  'Area Id10 (Insula) left',
#  'Area Id4 (Insula)',
#  'Area Id4 (Insula) right',
#  'Area Id4 (Insula) left',
#  'Area Id3 (Insula)',
#  'Area Id3 (Insula) right',
#  'Area Id3 (Insula) left',
#  'temporal lobe',
#  'superior temporal sulcus',
#  'Area STS2 (STS)',
#  'Area STS2 (STS) right',
#  'Area STS2 (STS) left',
#  'Area STS1 (STS)',
#  'Area STS1 (STS) right',
#  'Area STS1 (STS) left',
#  'occipito-temporal sulcus',
#  'Area OTS1 (OTS)',
#  'Area OTS1 (OTS) right',
#  'Area OTS1 (OTS) left',
#  'superior temporal gyrus',
#  'Area Te 3 (STG)',
#  'Area Te 3 (STG) right',
#  'Area Te 3 (STG) left',
#  'Area Te 2.2 (STG)',
#  'Area Te 2.2 (STG) right',
#  'Area Te 2.2 (STG) left',
#  'Area Te 2.1 (STG)',
#  'Area Te 2.1 (STG) right',
#  'Area Te 2.1 (STG) left',
#  "Heschl's gyrus",
#  'Area Te 1.1 (HESCHL)',
#  'Area Te 1.1 (HESCHL) right',
#  'Area Te 1.1 (HESCHL) left',
#  'Area Te 1.2 (HESCHL)',
#  'Area Te 1.2 (HESCHL) right',
#  'Area Te 1.2 (HESCHL) left',
#  'Area Te 1.0 (HESCHL)',
#  'Area Te 1.0 (HESCHL) right',
#  'Area Te 1.0 (HESCHL) left',
#  'parahippocampal gyrus',
#  'Area Ph1 (PhG)',
#  'Area Ph1 (PhG) right',
#  'Area Ph1 (PhG) left',
#  'Area Ph2 (PhG)',
#  'Area Ph2 (PhG) right',
#  'Area Ph2 (PhG) left',
#  'Area Ph3 (PhG)',
#  'Area Ph3 (PhG) right',
#  'Area Ph3 (PhG) left',
#  'collateral sulcus',
#  'Area CoS1 (CoS)',
#  'Area CoS1 (CoS) right',
#  'Area CoS1 (CoS) left',
#  'temporal insula',
#  'Area TI (STG)',
#  'Area TI (STG) right',
#  'Area TI (STG) left',
#  'Area TeI (STG)',
#  'Area TeI (STG) right',
#  'Area TeI (STG) left',
#  'fusiform gyrus',
#  'Area FG5 (FusG)',
#  'Area FG5 (FusG) right',
#  'Area FG5 (FusG) left',
#  'Area FG2 (FusG)',
#  'Area FG2 (FusG) right',
#  'Area FG2 (FusG) left',
#  'Area FG3 (FusG)',
#  'Area FG3 (FusG) right',
#  'Area FG3 (FusG) left',
#  'Area FG1 (FusG)',
#  'Area FG1 (FusG) right',
#  'Area FG1 (FusG) left',
#  'Area FG4 (FusG)',
#  'Area FG4 (FusG) right',
#  'Area FG4 (FusG) left',
#  'temporo-parietal junction',
#  'Area TPJ (STG, SMG)',
#  'Area TPJ (STG, SMG) right',
#  'Area TPJ (STG, SMG) left',
#  'occipital lobe',
#  'occipital cortex',
#  'Area hOc2 (V2, 18)',
#  'Area hOc2 (V2, 18) right',
#  'Area hOc2 (V2, 18) left',
#  'Area hOc1 (V1, 17, CalcS)',
#  'Area hOc1 (V1, 17, CalcS) right',
#  'Area hOc1 (V1, 17, CalcS) left',
#  'dorsal occipital cortex',
#  'Area hOc6 (POS)',
#  'Area hOc6 (POS) right',
#  'Area hOc6 (POS) left',
#  'Area hOc4d (Cuneus)',
#  'Area hOc4d (Cuneus) right',
#  'Area hOc4d (Cuneus) left',
#  'Area hOc3d (Cuneus)',
#  'Area hOc3d (Cuneus) right',
#  'Area hOc3d (Cuneus) left',
#  'ventral occipital cortex',
#  'Area hOc3v (LingG)',
#  'Area hOc3v (LingG) right',
#  'Area hOc3v (LingG) left',
#  'Area hOc4v (LingG)',
#  'Area hOc4v (LingG) right',
#  'Area hOc4v (LingG) left',
#  'lateral occipital cortex',
#  'Area hOc4lp (LOC)',
#  'Area hOc4lp (LOC) right',
#  'Area hOc4lp (LOC) left',
#  'Area hOc5 (LOC)',
#  'Area hOc5 (LOC) right',
#  'Area hOc5 (LOC) left',
#  'Area hOc4la (LOC)',
#  'Area hOc4la (LOC) right',
#  'Area hOc4la (LOC) left',
#  'limbic lobe',
#  'frontal cingulate gyrus',
#  'Area p24c (pACC)',
#  'Area p24c (pACC) right',
#  'Area p24c.pd24cd (pACC) right',
#  'Area p24c.pd24cv (pACC) right',
#  'Area p24c.pv24c (pACC) right',
#  'Area p24c (pACC) left',
#  'Area p24c.pd24cd (pACC) left',
#  'Area p24c.pd24cv (pACC) left',
#  'Area p24c.pv24c (pACC) left',
#  'Area 25 (sACC)',
#  'Area 25 (sACC) right',
#  'Area 25.25a (sACC) right',
#  'Area 25.25p (sACC) right',
#  'Area 25 (sACC) left',
#  'Area 25.25a (sACC) left',
#  'Area 25.25p (sACC) left',
#  'Area p24ab (pACC)',
#  'Area p24ab (pACC) right',
#  'Area p24ab.p24a (pACC) right',
#  'Area p24ab.p24b (pACC) right',
#  'Area p24ab (pACC) left',
#  'Area p24ab.p24a (pACC) left',
#  'Area p24ab.p24b (pACC) left',
#  'Area s32 (sACC)',
#  'Area s32 (sACC) right',
#  'Area s32 (sACC) left',
#  'Area 33 (ACC)',
#  'Area 33 (ACC) right',
#  'Area 33 (ACC) left',
#  'Area p32 (pACC)',
#  'Area p32 (pACC) right',
#  'Area p32 (pACC) left',
#  'Area s24 (sACC)',
#  'Area s24 (sACC) right',
#  'Area s24.s24a (sACC) right',
#  'Area s24.s24b (sACC) right',
#  'Area s24 (sACC) left',
#  'Area s24.s24a (sACC) left',
#  'Area s24.s24b (sACC) left',
#  'piriform cortex',
#  'Area PirT (PiriformCortexMesial, temporal)',
#  'Area PirT (PiriformCortexMesial, temporal) right',
#  'Area PirT.Tit (PiriformCortexMesial, Piriform temporal Area, Incisura temporalis) right',
#  'Area PirT.Tu (PiriformCortexMesial, Piriform temporal Area, Uncus) right',
#  'Area PirT (PiriformCortexMesial, temporal) left',
#  'Area PirT.Tit (PiriformCortexMesial, Piriform temporal Area, Incisura temporalis) left',
#  'Area PirT.Tu (PiriformCortexMesial, Piriform temporal Area, Uncus) left',
#  'Area PirTB (PiriformCortexMesial, temporobasal)',
#  'Area PirTB (PiriformCortexMesial, temporobasal) right',
#  'Area PirTB.TBd (PiriformCortexMesial, Piriform temporobasal Area, dorsal part) right',
#  'Area PirTB.TBv (PiriformCortexMesial, Piriform temporobasal Area, ventral part) right',
#  'Area PirTB (PiriformCortexMesial, temporobasal) left',
#  'Area PirTB.TBd (PiriformCortexMesial, Piriform temporobasal Area, dorsal part) left',
#  'Area PirTB.TBv (PiriformCortexMesial, Piriform temporobasal Area, ventral part) left',
#  'hippocampal formation',
#  'HATA (Hippocampus)',
#  'HATA (Hippocampus) right',
#  'HATA (Hippocampus) left',
#  'CA3 (Hippocampus)',
#  'CA3 (Hippocampus) right',
#  'CA3 (Hippocampus) left',
#  'TrS (Hippocampus, Transsubiculum)',
#  'TrS (Hippocampus, Transsubiculum) right',
#  'TrS (Hippocampus, Transsubiculum) left',
#  'Subc (Hippocampus, Subicular complex)',
#  'Subc (Hippocampus, Subicular complex) right',
#  'Subc.PaS (Hippocampus, Parasubiculum) right',
#  'Subc.PreS (Hippocampus, Presubiculum) right',
#  'Subc.ProS (Hippocampus, Prosubiculum) right',
#  'Subc.Sub (Hippocampus, Subiculum) right',
#  'Subc (Hippocampus, Subicular complex) left',
#  'Subc.PaS (Hippocampus, Parasubiculum) left',
#  'Subc.PreS (Hippocampus, Presubiculum) left',
#  'Subc.ProS (Hippocampus, Prosubiculum) left',
#  'Subc.Sub (Hippocampus, Subiculum) left',
#  'DG (Hippocampus)',
#  'DG (Hippocampus) right',
#  'DG (Hippocampus) left',
#  'CA2 (Hippocampus)',
#  'CA2 (Hippocampus) right',
#  'CA2 (Hippocampus) left',
#  'Area EC (Hippocampal Region, Entorhinal Cortex)',
#  'Area EC (Hippocampal Region, Entorhinal Cortex) right',
#  'Area EC (Hippocampal Region, Entorhinal Cortex) left',
#  'CA1 (Hippocampus)',
#  'CA1 (Hippocampus) right',
#  'CA1 (Hippocampus) left',
#  'olfactory cortex',
#  'TuTi (Basal Forebrain, Terminal islands)',
#  'TuTi (Basal Forebrain, Terminal islands) right',
#  'TuTi (Basal Forebrain, Terminal islands) left',
#  'Tu (Basal Forebrain, Tuberculum)',
#  'Tu (Basal Forebrain, Tuberculum) right',
#  'Tu (Basal Forebrain, Tuberculum) left',
#  'mesencephalon',
#  'midbrain tegmentum',
#  'midbrain',
#  'substantia nigra',
#  'SNC (Midbrain, Substantia Nigra pars compacta)',
#  'SNC (Midbrain, Substantia Nigra pars compacta) right',
#  'SNC (Midbrain, Substantia Nigra pars compacta) left',
#  'SNR (Midbrain, Substantia Nigra pars reticulata)',
#  'SNR (Midbrain, Substantia Nigra pars reticulata) right',
#  'SNR (Midbrain, Substantia Nigra pars reticulata) left',
#  'nucleus ruber (parvocellular part)',
#  'NRp (Midbrain, Nucleus Ruber, parvocellular part)',
#  'NRp (Midbrain, Nucleus Ruber, parvocellular part) right',
#  'NRp (Midbrain, Nucleus Ruber, parvocellular part) left',
#  'nucleus ruber (magnocellular part)',
#  'NRm (Midbrain, Nucleus Ruber, magnocellular part)',
#  'NRm (Midbrain, Nucleus Ruber, magnocellular part) right',
#  'NRm (Midbrain, Nucleus Ruber, magnocellular part) left',
#  'metencephalon',
#  'cerebellum',
#  'cerebellar nuclei',
#  'Ninterp (Cerebellum, Interposed Nucleus)',
#  'Ninterp (Cerebellum, Interposed Nucleus) right',
#  'Ninterp (Cerebellum, Interposed Nucleus) left',
#  'dentate nucleus',
#  'Ndentv (Cerebellum, Ventral Dentate Nucleus)',
#  'Ndentv (Cerebellum, Ventral Dentate Nucleus) right',
#  'Ndentv (Cerebellum, Ventral Dentate Nucleus) left',
#  'Ndentd (Cerebellum, Dorsal Dentate Nucleus)',
#  'Ndentd (Cerebellum, Dorsal Dentate Nucleus) right',
#  'Ndentd (Cerebellum, Dorsal Dentate Nucleus) left',
#  'fastigial nucleus',
#  'Nfast (Cerebellum, Fastigial Nucleus)',
#  'Nfast (Cerebellum, Fastigial Nucleus) right',
#  'Nfast (Cerebellum, Fastigial Nucleus) left',
#  'diencephalon',
#  'subthalamus',
#  'STN (Subthalamus)',
#  'STN (Subthalamus) right',
#  'STN (Subthalamus) left',
#  'thalamus',
#  'ventral thalamus',
#  'Rt (Thalamus, reticular Nucleus)',
#  'Rt (Thalamus, reticular Nucleus) right',
#  'Rt (Thalamus, reticular Nucleus) left',
#  'ZI (Thalamus, zona incerta)',
#  'ZI (Thalamus, zona incerta) right',
#  'ZI (Thalamus, zona incerta) left',
#  'metathalamus',
#  'medial geniculate body',
#  'CGM (Metathalamus)',
#  'CGM (Metathalamus) right',
#  'CGM (Metathalamus) left',
#  'lateral geniculate body',
#  'CGL (Metathalamus)',
#  'CGL (Metathalamus) right',
#  'CGL (Metathalamus) left',
#  'dorsal thalamus',
#  'medial group',
#  'MV (Thalamus, medioventral Nucleus)',
#  'MV (Thalamus, medioventral Nucleus) right',
#  'MV (Thalamus, medioventral Nucleus) left',
#  'MD (Thalamus, mediodorsal Nucleus)',
#  'MD (Thalamus, mediodorsal Nucleus) right',
#  'MD (Thalamus, mediodorsal Nucleus) left',
#  'Pv (Thalamus, paraventricular Nucleus)',
#  'Pv (Thalamus, paraventricular Nucleus) right',
#  'Pv (Thalamus, paraventricular Nucleus) left',
#  'posterior group',
#  'Po (Thalamus, posterior Nucleus)',
#  'Po (Thalamus, posterior Nucleus) right',
#  'Po (Thalamus, posterior Nucleus) left',
#  'PUm (Thalamus, medial pulvinar)',
#  'PUm (Thalamus, medial pulvinar) right',
#  'PUm (Thalamus, medial pulvinar) left',
#  'PUl (Thalamus, lateral pulvinar)',
#  'PUl (Thalamus, lateral pulvinar) right',
#  'PUl (Thalamus, lateral pulvinar) left',
#  'Li (Thalamus, limitans Nucleus)',
#  'Li (Thalamus, limitans Nucleus) right',
#  'Li (Thalamus, limitans Nucleus) left',
#  'Sg (Thalamus, suprageniculate Nucleus)',
#  'Sg (Thalamus, suprageniculate Nucleus) right',
#  'Sg (Thalamus, suprageniculate Nucleus) left',
#  'LP (Thalamus, lateral posterior Nucleus)',
#  'LP (Thalamus, lateral posterior Nucleus) right',
#  'LP (Thalamus, lateral posterior Nucleus) left',
#  'PUi (Thalamus, inferior pulvinar)',
#  'PUi (Thalamus, inferior pulvinar) right',
#  'PUi (Thalamus, inferior pulvinar) left',
#  'PUa (Thalamus, anterior pulvinar)',
#  'PUa (Thalamus, anterior pulvinar) right',
#  'PUa (Thalamus, anterior pulvinar) left',
#  'anterior group',
#  'LD (Thalamus, lateral dorsal Nucleus)',
#  'LD (Thalamus, lateral dorsal Nucleus) right',
#  'LD (Thalamus, lateral dorsal Nucleus) left',
#  'AV (Thalamus, anteroventral Nucleus)',
#  'AV (Thalamus, anteroventral Nucleus) right',
#  'AV (Thalamus, anteroventral Nucleus) left',
#  'AM (Thalamus, anteromedial Nucleus)',
#  'AM (Thalamus, anteromedial Nucleus) right',
#  'AM (Thalamus, anteromedial Nucleus) left',
#  'ventral group',
#  'VPMpc (Thalamus, ventral posterior medial Nucleus, parvocellular part)',
#  'VPMpc (Thalamus, ventral posterior medial Nucleus, parvocellular part) right',
#  'VPMpc (Thalamus, ventral posterior medial Nucleus, parvocellular part) left',
#  'VPi (Thalamus, ventroposterior inferior Nucleus)',
#  'VPi (Thalamus, ventroposterior inferior Nucleus) right',
#  'VPi (Thalamus, ventroposterior inferior Nucleus) left',
#  'VPL (Thalamus, ventral posterior lateral Nucleus)',
#  'VPL (Thalamus, ventral posterior lateral Nucleus) right',
#  'VPL (Thalamus, ventral posterior lateral Nucleus) left',
#  'VLP (Thalamus, ventral lateral posterior Nucleus)',
#  'VLP (Thalamus, ventral lateral posterior Nucleus) right',
#  'VLP (Thalamus, ventral lateral posterior Nucleus) left',
#  'VIM (Thalamus, ventral intermediate Nucleus)',
#  'VIM (Thalamus, ventral intermediate Nucleus) right',
#  'VIM (Thalamus, ventral intermediate Nucleus) left',
#  'VM (Thalamus, ventral medial Nucleus)',
#  'VM (Thalamus, ventral medial Nucleus) right',
#  'VM (Thalamus, ventral medial Nucleus) left',
#  'VA (Thalamus, ventral anterior Nucleus (ventral))',
#  'VA (Thalamus, ventral anterior Nucleus (ventral)) right',
#  'VA (Thalamus, ventral anterior Nucleus (ventral)) left',
#  'VLA (Thalamus, ventral lateral anterior Nucleus)',
#  'VLA (Thalamus, ventral lateral anterior Nucleus) right',
#  'VLA (Thalamus, ventral lateral anterior Nucleus) left',
#  'VAmc (Thalamus, ventral anterior Nucleus, magnocellular part)',
#  'VAmc (Thalamus, ventral anterior Nucleus, magnocellular part) right',
#  'VAmc (Thalamus, ventral anterior Nucleus, magnocellular part) left',
#  'VPM (Thalamus, ventral posterior medial Nucleus)',
#  'VPM (Thalamus, ventral posterior medial Nucleus) right',
#  'VPM (Thalamus, ventral posterior medial Nucleus) left',
#  'intralaminar group',
#  'sPf (Thalamus, subparafascicular Nucleus)',
#  'sPf (Thalamus, subparafascicular Nucleus) right',
#  'sPf (Thalamus, subparafascicular Nucleus) left',
#  'Pf (Thalamus, parafascicular Nucleus)',
#  'Pf (Thalamus, parafascicular Nucleus) right',
#  'Pf (Thalamus, parafascicular Nucleus) left',
#  'CM (Thalamus, centromedian Nucleus)',
#  'CM (Thalamus, centromedian Nucleus) right',
#  'CM (Thalamus, centromedian Nucleus) left',
#  'CL (Thalamus, anterior intralaminar nuclei)',
#  'CL (Thalamus, anterior intralaminar nuclei) right',
#  'CL (Thalamus, anterior intralaminar nuclei) left']

# %%
# We can iterate the brain divisions in the parcellation
[region.name for region in julich_brain.children]
# Out:
# ['telencephalon', 'mesencephalon', 'metencephalon', 'diencephalon']

# %%
# We can also iterate only the leaves of the tree
[region.name for region in julich_brain.leaves]
# Out:
# ['Direct segment of the left arcuate fasciculus',
#  'Direct segment of the right arcuate fasciculus',
#  'Anterior segment of the left arcuate fasciculus',
#  'Anterior segment of the right arcuate fasciculus',
#  'Posterior segment of the left arcuate fasciculus',
#  'Posterior segment of the right arcuate fasciculus',
#  'Left long cingulate fibres',
#  'Right long cingulate fibres',
#  'Left short cingulate fibres',
#  'Right short cingulate fibres',
#  'Left temporal cingulate fibres',
#  'Right temporal cingulate fibres',
#  'CorpusCallosum_Body',
#  'CorpusCallosum_Genu',
#  'CorpusCallosum_Rostrum',
#  'CorpusCallosum_Splenium',
#  'Left corticospinal tract',
#  'Right corticospinal tract',
#  'ExternalCapsule Left',
#  'ExternalCapsule Right',
#  'Left fornix',
#  'Right fornix',
#  'Left inferior fronto-occipital fasciculus',
#  'Right inferior fronto-occipital fasciculus',
#  'Left inferior longitudinal fasciculus',
#  'Right inferior longitudinal fasciculus',
#  'InferiorLongitudinal_Lateral Left',
#  'InferiorLongitudinal_Lateral Right',
#  'MediumLongitudinal Left',
#  'MediumLongitudinal Right',
#  'SpinoThalamicTract Left',
#  'SpinoThalamicTract Right',
#  'ThalamicRadiations_Anterior Left',
#  'ThalamicRadiations_Anterior Right',
#  'ThalamicRadiations_Posterior Left',
#  'ThalamicRadiations_Posterior Right',
#  'Left uncinate fasciculus',
#  'Right uncinate fasciculus']

# %%
# The most basic way is to search for all regions matching a particular string:
julich_brain.find('Right corticospinal tract')
# Out:
# [<Region(identifier='juelich/iav/atlas/v1.0.0/5_RIGHT_CORTICOSPINAL_TRACT', name='Right corticospinal tract', species='Homo sapiens')>]

# %%
# You can filter the children and querying the root node by:
julich_brain.find('v1', filter_children=True)
# Out:
# []

# %%
space = atlas.spaces.get("Thalamus")
print(space.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 space = atlas.spaces.get("Thalamus")
#       2 print(space.name)
#
# NameError: name 'atlas' is not defined

# %%
STN_R = siibra.get_region('DEEP_WHITE_MATTER_FIBRE_BUNDLES', 'Right corticospinal tract')
print(STN_R)
# Out:
# Right corticospinal tract

# %%
print(STN_R.spaces)
# Out:
# Loading preconfigured Space instances: 100%|████████████████████████████████████████| 10/10 [00:00<00:00, 528.52Space/s]
# Loading preconfigured Map instances:  88%|███████████████████████████████████████▋     | 52/59 [00:01<00:00, 29.82Map/s][siibra:WARNING] Non unique indices encountered in Waxholm Space atlas of the Sprague Dawley rat brain delineations v1.01: {<MapIndex(volume=0, label=2, fragment=None)>}
# Loading preconfigured Map instances: 100%|█████████████████████████████████████████████| 59/59 [00:01<00:00, 30.87Map/s]
# [siibra:WARNING] Map registry contains multiple classes: SparseMap, Map
# InstanceTable:
#  - MNI_152_ICBM_2009C_NONLINEAR_ASYMMETRIC

# %%
print(STN_R.name)
# Out:
# Right corticospinal tract

# %%
space = STN_R.spaces.get("MNI_152_ICBM_2009C_NONLINEAR_ASYMMETRIC")
print(space)
# Out:
# MNI 152 ICBM 2009c Nonlinear Asymmetric

# %%
from pprint import pprint
props = STN_R.spatial_props(space=space)
pprint(props)
# Out:
# [ComponentSpatialProperties(centroid=<Point((21.519917073893083, -17.90626388271879, 15.246853250407227), space='minds/core/referencespace/v1.0.0/dafcffc5-4826-4bf1-8ff6-46b8a31ff8e2', sigma_mm=0.0)>,
#                             volume=np.float64(6753.0)),
#  ComponentSpatialProperties(centroid=<Point((6.24930747922437, -23.612188365650965, -34.66759002770083), space='minds/core/referencespace/v1.0.0/dafcffc5-4826-4bf1-8ff6-46b8a31ff8e2', sigma_mm=0.0)>,
#                             volume=np.float64(361.0)),
#  ComponentSpatialProperties(centroid=<Point((7.0, -32.80952380952381, -25.42857142857143), space='minds/core/referencespace/v1.0.0/dafcffc5-4826-4bf1-8ff6-46b8a31ff8e2', sigma_mm=0.0)>,
#                             volume=np.float64(21.0))]

# %%
dir(STN_R)
# Out:
# ['LICENSE',
#  '_ASSIGNMENT_CACHE',
#  '_CACHED_MATCHES',
#  '_GETMASK_CACHE',
#  '_GETMASK_CACHE_MAX_ENTRIES',
#  '_NodeMixin__attach',
#  '_NodeMixin__check_children',
#  '_NodeMixin__check_loop',
#  '_NodeMixin__children',
#  '_NodeMixin__children_or_empty',
#  '_NodeMixin__detach',
#  '_NodeMixin__parent',
#  '__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_accepted_flags',
#  '_configuration_folder',
#  '_description',
#  '_id',
#  '_path',
#  '_post_attach',
#  '_post_attach_children',
#  '_post_detach',
#  '_post_detach_children',
#  '_pre_attach',
#  '_pre_attach_children',
#  '_pre_detach',
#  '_pre_detach_children',
#  '_prerelease',
#  '_publications',
#  '_regex_re',
#  '_spec',
#  '_species_cached',
#  '_str_aliases',
#  '_supported_spaces',
#  'ancestors',
#  'anchestors',
#  'assign',
#  'authors',
#  'children',
#  'clear_registry',
#  'compute_centroids',
#  'copy',
#  'datasets',
#  'depth',
#  'descendants',
#  'description',
#  'find',
#  'get_boundingbox',
#  'get_instance',
#  'get_regional_map',
#  'get_regional_mask',
#  'get_related_regions',
#  'has_parent',
#  'height',
#  'id',
#  'includes',
#  'intersection',
#  'intersects',
#  'is_leaf',
#  'is_root',
#  'iter_path_reverse',
#  'key',
#  'leaves',
#  'mapped_in_space',
#  'match',
#  'matches',
#  'modality',
#  'name',
#  'names',
#  'parcellation',
#  'parent',
#  'path',
#  'publications',
#  'registry',
#  'render_tree',
#  'rgb',
#  'root',
#  'separator',
#  'shortname',
#  'siblings',
#  'size',
#  'spaces',
#  'spatial_props',
#  'species',
#  'supported_spaces',
#  'tree2str',
#  'urls']

# %%
STN_map = STN_R.get_regional_map(space, maptype="statistical")
print(STN_map)
# Out:
# Volume siibra-map-v0.0.1_mni152-dwm-continuous - volume 13 in space MNI 152 ICBM 2009c Nonlinear Asymmetric

# %%
plotting.plot_glass_brain(STN_map.fetch(), alpha=1, cmap="RdBu", symmetric_cbar=True)

# %%
#https://siibra-python.readthedocs.io/en/latest/examples/tutorials/2025-paper-fig3.html#sphx-glr-examples-tutorials-2025-paper-fig3-py
genes = ["PTEN", "NLGN1"]
gene_expressions = siibra.features.get(STN_R, "gene expressions", gene=genes)
print("\n".join(gene_expressions[0].urls))
fig, axs = plt.subplots(1, 1, figsize=(4, 3.5))
gene_expressions[0].plot(ax=axs)
# Out:
# [siibra:INFO] 'gene expressions' decoded as feature type/s: ['GeneExpressions'].
# https://doi.org/10.1038%2Fnature11405
# <Axes: title={'center': 'Gene expression STN (Subthalamus) right'}, xlabel='gene', ylabel='expression level'>

# %%
dir(STN_map)
# Out:
# ['IMAGE_FORMATS',
#  'MESH_FORMATS',
#  'SUPPORTED_FORMATS',
#  '_ASSIGNMENT_CACHE',
#  '_FETCH_CACHE',
#  '_FETCH_CACHE_MAX_ENTRIES',
#  '_FORMAT_LOOKUP',
#  '__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_boundingbox',
#  '_name',
#  '_points_inside',
#  '_providers',
#  '_space_spec',
#  'assign',
#  'compute_spatial_props',
#  'datasets',
#  'draw_samples',
#  'evaluate_points',
#  'fetch',
#  'fetch_connected_components',
#  'find_peaks',
#  'formats',
#  'fragments',
#  'get_boundingbox',
#  'intersection',
#  'intersects',
#  'name',
#  'providers',
#  'provides_image',
#  'provides_mesh',
#  'space',
#  'species',
#  'variant']

# %%
STN_map.provides_mesh
# Out:
# False

# %%
STN_R = siibra.get_region("JULICH_BRAIN_CYTOARCHITECTONIC_ATLAS_V3_1", "STN (Subthalamus) left")
space = STN_R.spaces.get("MNI_152_ICBM_2009C_NONLINEAR_ASYMMETRIC")
STN_map = STN_R.get_regional_map(space, maptype="statistical")
# Out:
# Loading preconfigured Space instances: 100%|████████████████████████████████████████| 10/10 [00:00<00:00, 413.35Space/s]
# Loading preconfigured Map instances:  83%|█████████████████████████████████████▎       | 49/59 [00:01<00:00, 32.19Map/s][siibra:WARNING] Non unique indices encountered in Waxholm Space atlas of the Sprague Dawley rat brain delineations v1.01: {<MapIndex(volume=0, label=2, fragment=None)>}
# Loading preconfigured Map instances: 100%|█████████████████████████████████████████████| 59/59 [00:01<00:00, 34.26Map/s]
# [siibra:WARNING] Map registry contains multiple classes: Map, SparseMap

# %%
NIfTI_STN_R = STN_map.fetch()
type(NIfTI_STN_R)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
# Get voxel data as a numpy array
STN_R_data = NIfTI_STN_R.get_fdata()

# %%
# Basic stats
print("Number of voxels:", STN_R_data.size)
print("Min probability:", STN_R_data.min())
print("Max probability:", STN_R_data.max())
print("Mean probability:", STN_R_data.mean())
print("Standard deviation:", STN_R_data.std())
# Out:
# Number of voxels: 8530021
# Min probability: 0.0
# Max probability: 0.8974618315696716
# Mean probability: 3.8260651421661814e-05
# Standard deviation: 0.004315333140739117

# %%
print(STN_R_data.shape)
# Out:
# (193, 229, 193)

# %%
STN_R_data.nonzero()
# Out:
# (array([78, 78, 78, ..., 91, 91, 91], shape=(1383,)),
#  array([113, 113, 114, ..., 124, 124, 124], shape=(1383,)),
#  array([69, 70, 68, ..., 66, 67, 68], shape=(1383,)))

# %%
# Assuming STN_R_data is a 3D NumPy array
nonzero_indices = np.argwhere(STN_R_data > 0)             # Shape: (N, 3)
nonzero_values = STN_R_data[STN_R_data > 0]               # Shape: (N,)

# Combine indices and values into a single array: (x, y, z, value)
nonzero_voxels = np.hstack((nonzero_indices, nonzero_values[:, np.newaxis]))

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Required for 3D plotting
# %matplotlib inline
# %matplotlib widget

# Step 1: Get coordinates and values of non-zero voxels
nonzero_indices = np.argwhere(STN_R_data > 0)
nonzero_values = STN_R_data[STN_R_data > 0]

# Step 2: Plot as 3D scatter
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Split coordinates
x, y, z = nonzero_indices[:, 0], nonzero_indices[:, 1], nonzero_indices[:, 2]

# Normalize values for color mapping
#norm_values = (nonzero_values - nonzero_values.min()) / (nonzero_values.ptp())

# Scatter plot
sc = ax.scatter(x, y, z, c=nonzero_values, cmap='viridis', s=2)

# Color bar
plt.colorbar(sc, ax=ax, label='Normalized Value')

# Labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Scatter of Non-Zero Voxels')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Required for 3D plotting
# %matplotlib inline
# %matplotlib widget

# Step 1: Get coordinates and values of non-zero voxels
nonzero_indices = np.argwhere(STN_R_data > 0)
nonzero_values = STN_R_data[STN_R_data > 0]

# Step 2: Plot as 3D scatter
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Split coordinates
x, y, z = nonzero_indices[:, 0], nonzero_indices[:, 1], nonzero_indices[:, 2]

# Normalize values for color mapping
#norm_values = (nonzero_values - nonzero_values.min()) / (nonzero_values.ptp())

# Scatter plot
sc = ax.scatter(x, y, z, c=nonzero_values, cmap='viridis', s=2)

# Color bar
plt.colorbar(sc, ax=ax, label='Normalized Value')

# Labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Scatter of Non-Zero Voxels')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
